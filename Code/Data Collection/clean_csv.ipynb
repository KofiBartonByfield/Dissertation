# %% [markdown]
# # Cleaning the Data

# %%
import pandas as pd

# %%
dataset = pd.read_csv('../../Data/Data Sets/raw_dataset.csv', index_col=False)

# look at the data 
display(dataset)
# Out:
#       StopCount  StopCountDrugs   LSOA21CD      Borough  PopulationLSOA  \
# 0         132.0           115.0  E01006434     Knowsley            1518
# 1         109.0            92.0  E01006435     Knowsley            1524
# 2         305.0           267.0  E01006436     Knowsley            1457
# 3         639.0           520.0  E01006437     Knowsley            1387
# 4          38.0            32.0  E01006438     Knowsley            1153
# ...         ...             ...        ...          ...             ...
# 5912       13.0             3.0  E01004660  Westminster            1430
# 5913      263.0           103.0  E01004661  Westminster            1998
# 5914       13.0             7.0  E01004662  Westminster            1318
# 5915       43.0            24.0  E01004663  Westminster            1417
# 5916      135.0            61.0  E01004665  Westminster            1456
#
#        BAME  IncomeDomainScore  CrimeSum  DrugCrimeSum  MeanHousePrice  \
# 0      1.91              932.0     228.0          23.0        123955.0
# 1      3.35              782.0     149.0          18.0        134664.0
# 2      3.29              613.0     307.0          58.0        111733.0
# 3      3.03             1649.0     921.0          72.0        119648.0
# 4      5.29            17818.0      91.0           7.0        331221.0
# ...     ...                ...       ...           ...             ...
# 5912  41.54            31573.0     344.0           1.0       1655186.0
# 5913  49.80            14052.0     737.0          17.0       1283005.0
# 5914  31.64            29619.0     306.0           2.0       1427386.0
# 5915  37.47            19021.0     333.0          15.0       1817948.0
# 5916  60.10             2928.0     299.0          11.0        425000.0
#
#       PoliceDept
# 0     Merseyside
# 1     Merseyside
# 2     Merseyside
# 3     Merseyside
# 4     Merseyside
# ...          ...
# 5912      London
# 5913      London
# 5914      London
# 5915      London
# 5916      London
#
# [5917 rows x 11 columns]

# %% [markdown]
# # Adressing Missing Data

# %%
def missing_rows():
    for col in dataset:

        na_count = sum(dataset[col].isna())
        if na_count > 0:
            print(f'\nColumn : {col} has: {na_count} values')

missing_rows()
# Out:
# Column : StopCount has: 189 values
#
# Column : StopCountDrugs has: 189 values
#
# Column : IncomeDomainScore has: 369 values
#
# Column : CrimeSum has: 21 values
#
# Column : DrugCrimeSum has: 636 values
#
# Column : MeanHousePrice has: 524 values

# %% [markdown]
# NAs for StopCount, StopCountDrugs, CrimeSum and DrugCrimeSum can all be replaced with 0

# %%
# dataset['StopCount'].fillna(0, inplace=True)

dataset.fillna({'StopCount': 0,
                'StopCountDrugs': 0,
                'CrimeSum': 0,
                'DrugCrimeSum': 0}, inplace=True)

missing_rows()
# Out:
# Column : IncomeDomainScore has: 369 values
#
# Column : MeanHousePrice has: 524 values

# %%
# Calculate mean values for London and Merseyside separately
mean_values = dataset.groupby('PoliceDept')[['IncomeDomainScore', 'MeanHousePrice']].transform('mean')

# Fill missing values for IncomeDomainScore and MeanHousePrice based on their respective groups
dataset['IncomeDomainScore'] = dataset.groupby('PoliceDept')['IncomeDomainScore'].transform(
    lambda x: x.fillna(x.mean())
)

dataset['MeanHousePrice'] = dataset.groupby('PoliceDept')['MeanHousePrice'].transform(
    lambda x: x.fillna(x.mean())
)

# Verify the dataset
display(dataset)
missing_rows()
# Out:
#       StopCount  StopCountDrugs   LSOA21CD      Borough  PopulationLSOA  \
# 0         132.0           115.0  E01006434     Knowsley            1518
# 1         109.0            92.0  E01006435     Knowsley            1524
# 2         305.0           267.0  E01006436     Knowsley            1457
# 3         639.0           520.0  E01006437     Knowsley            1387
# 4          38.0            32.0  E01006438     Knowsley            1153
# ...         ...             ...        ...          ...             ...
# 5912       13.0             3.0  E01004660  Westminster            1430
# 5913      263.0           103.0  E01004661  Westminster            1998
# 5914       13.0             7.0  E01004662  Westminster            1318
# 5915       43.0            24.0  E01004663  Westminster            1417
# 5916      135.0            61.0  E01004665  Westminster            1456
#
#        BAME  IncomeDomainScore  CrimeSum  DrugCrimeSum  MeanHousePrice  \
# 0      1.91              932.0     228.0          23.0        123955.0
# 1      3.35              782.0     149.0          18.0        134664.0
# 2      3.29              613.0     307.0          58.0        111733.0
# 3      3.03             1649.0     921.0          72.0        119648.0
# 4      5.29            17818.0      91.0           7.0        331221.0
# ...     ...                ...       ...           ...             ...
# 5912  41.54            31573.0     344.0           1.0       1655186.0
# 5913  49.80            14052.0     737.0          17.0       1283005.0
# 5914  31.64            29619.0     306.0           2.0       1427386.0
# 5915  37.47            19021.0     333.0          15.0       1817948.0
# 5916  60.10             2928.0     299.0          11.0        425000.0
#
#       PoliceDept
# 0     Merseyside
# 1     Merseyside
# 2     Merseyside
# 3     Merseyside
# 4     Merseyside
# ...          ...
# 5912      London
# 5913      London
# 5914      London
# 5915      London
# 5916      London
#
# [5917 rows x 11 columns]

# %% [markdown]
# # Normalising Scores

# %%
def convert_to_z_scores(df, column_names):
    """
    Convert multiple columns in the DataFrame to the number of standard deviations (z-scores) from the mean.
    This operation is done separately for each group (e.g., London and Merseyside).
    
    Parameters:
    df (pd.DataFrame): The DataFrame containing the columns to transform.
    column_names (list): A list of column names to convert to Z-scores.
    
    Returns:
    pd.DataFrame: The DataFrame with Z-scores added as new columns for the specified columns.
    """
    # Group by the specified group column (London/Merseyside)
    df_copy = df.copy()
    
    for column_name in column_names:
        # Apply Z-score transformation within each group
        df_copy[column_name + '_z'] = df_copy.groupby('PoliceDept')[column_name].transform(
            lambda x: ((x - x.mean()) / x.std()).round(3)
        )
    
    return df_copy

# %%
# List of columns to convert to Z-scores
columns_to_convert = ['StopCount', 'BAME', 'MeanHousePrice', 'CrimeSum', 'DrugCrimeSum', 'IncomeDomainScore']

# Create new columns in your 'merseyside' DataFrame
dataset = convert_to_z_scores(dataset, columns_to_convert)


dataset
# Out:
#       StopCount  StopCountDrugs   LSOA21CD      Borough  PopulationLSOA  \
# 0         132.0           115.0  E01006434     Knowsley            1518
# 1         109.0            92.0  E01006435     Knowsley            1524
# 2         305.0           267.0  E01006436     Knowsley            1457
# 3         639.0           520.0  E01006437     Knowsley            1387
# 4          38.0            32.0  E01006438     Knowsley            1153
# ...         ...             ...        ...          ...             ...
# 5912       13.0             3.0  E01004660  Westminster            1430
# 5913      263.0           103.0  E01004661  Westminster            1998
# 5914       13.0             7.0  E01004662  Westminster            1318
# 5915       43.0            24.0  E01004663  Westminster            1417
# 5916      135.0            61.0  E01004665  Westminster            1456
#
#        BAME  IncomeDomainScore  CrimeSum  DrugCrimeSum  MeanHousePrice  \
# 0      1.91              932.0     228.0          23.0        123955.0
# 1      3.35              782.0     149.0          18.0        134664.0
# 2      3.29              613.0     307.0          58.0        111733.0
# 3      3.03             1649.0     921.0          72.0        119648.0
# 4      5.29            17818.0      91.0           7.0        331221.0
# ...     ...                ...       ...           ...             ...
# 5912  41.54            31573.0     344.0           1.0       1655186.0
# 5913  49.80            14052.0     737.0          17.0       1283005.0
# 5914  31.64            29619.0     306.0           2.0       1427386.0
# 5915  37.47            19021.0     333.0          15.0       1817948.0
# 5916  60.10             2928.0     299.0          11.0        425000.0
#
#       PoliceDept  StopCount_z  BAME_z  MeanHousePrice_z  CrimeSum_z  \
# 0     Merseyside        0.634  -0.673            -0.769       0.151
# 1     Merseyside        0.446  -0.505            -0.660      -0.146
# 2     Merseyside        2.047  -0.512            -0.893       0.449
# 3     Merseyside        4.774  -0.542            -0.813       2.759
# 4     Merseyside       -0.133  -0.279             1.342      -0.364
# ...          ...          ...     ...               ...         ...
# 5912      London       -0.251  -0.195             1.973       0.514
# 5913      London        3.002   0.246             1.220       1.868
# 5914      London       -0.251  -0.724             1.512       0.384
# 5915      London        0.139  -0.413             2.302       0.477
# 5916      London        1.336   0.797            -0.516       0.359
#
#       DrugCrimeSum_z  IncomeDomainScore_z
# 0              0.382               -1.087
# 1              0.204               -1.102
# 2              1.629               -1.119
# 3              2.128               -1.015
# 4             -0.188                0.605
# ...              ...                  ...
# 5912          -0.373                1.830
# 5913           0.607               -0.181
# 5914          -0.312                1.606
# 5915           0.484                0.390
# 5916           0.239               -1.457
#
# [5917 rows x 17 columns]

# %%
dataset = dataset[['LSOA21CD', 'Borough', 'StopCount_z', 'StopCount', 'PoliceDept', 'MeanHousePrice_z', 'CrimeSum_z', 'BAME_z', 'DrugCrimeSum_z', 'IncomeDomainScore_z']]

# %%
dataset.to_csv('../../Data/Data Sets/cleaned_dataset.csv', index=False)
