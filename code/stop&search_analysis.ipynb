# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/stop_and_search_cleaned.csv')

display(df)
# Out:
#                               Date           Type   Latitude  Longitude  \
# 0        2014-09-30 23:35:00+00:00  Person search  51.718631  -3.059401
# 1        2014-09-30 23:50:00+00:00  Person search  51.583966  -2.994404
# 2        2014-10-01 00:20:00+00:00  Person search  51.731833  -3.066993
# 3        2014-10-01 01:15:00+00:00  Person search  51.824979  -3.018959
# 4        2014-10-01 08:20:00+00:00  Person search  51.591295  -2.987910
# ...                            ...            ...        ...        ...
# 4295837  2024-11-30 21:26:00+00:00  Person search  52.376361  -1.747030
# 4295838  2024-11-30 21:40:00+00:00  Person search  52.371651  -1.752065
# 4295839  2024-11-30 21:56:00+00:00  Person search  52.371651  -1.752065
# 4295840  2024-11-30 22:06:00+00:00  Person search  52.371651  -1.752065
# 4295841  2024-11-30 22:22:00+00:00  Person search  52.599007  -2.062349
#
#         Gender Age range Officer-defined ethnicity  \
# 0          NaN     25-34                     Other
# 1         Male   over 34                     Other
# 2         Male   over 34                     White
# 3         Male   over 34                     White
# 4         Male     25-34                     White
# ...        ...       ...                       ...
# 4295837   Male     10-17                     White
# 4295838   Male     10-17                     White
# 4295839   Male     10-17                     White
# 4295840   Male     10-17                     White
# 4295841   Male     25-34                     White
#
#                                                Legislation  \
# 0        Police and Criminal Evidence Act 1984 (section 1)
# 1                    Misuse of Drugs Act 1971 (section 23)
# 2        Police and Criminal Evidence Act 1984 (section 1)
# 3        Police and Criminal Evidence Act 1984 (section 1)
# 4                    Misuse of Drugs Act 1971 (section 23)
# ...                                                    ...
# 4295837  Police and Criminal Evidence Act 1984 (section 1)
# 4295838  Police and Criminal Evidence Act 1984 (section 1)
# 4295839  Police and Criminal Evidence Act 1984 (section 1)
# 4295840  Police and Criminal Evidence Act 1984 (section 1)
# 4295841  Police and Criminal Evidence Act 1984 (section 1)
#
#                  Object of search                            Outcome  \
# 0                    Stolen goods  Nothing found - no further action
# 1                Controlled drugs  Nothing found - no further action
# 2                Controlled drugs  Nothing found - no further action
# 3                    Stolen goods  Nothing found - no further action
# 4                Controlled drugs                                NaN
# ...                           ...                                ...
# 4295837         Offensive weapons       A no further action disposal
# 4295838         Offensive weapons       A no further action disposal
# 4295839         Offensive weapons       A no further action disposal
# 4295840         Offensive weapons       A no further action disposal
# 4295841  Article for use in theft               Community resolution
#
#         Outcome linked to object of search  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 4295837                                NaN
# 4295838                                NaN
# 4295839                                NaN
# 4295840                                NaN
# 4295841                                NaN
#
#         Removal of more than just outer clothing    Police_Dept  \
# 0                                            NaN          gwent
# 1                                            NaN          gwent
# 2                                            NaN          gwent
# 3                                            NaN          gwent
# 4                                            NaN          gwent
# ...                                          ...            ...
# 4295837                                    False  west_midlands
# 4295838                                    False  west_midlands
# 4295839                                    False  west_midlands
# 4295840                                    False  west_midlands
# 4295841                                    False  west_midlands
#
#         Self_defined_ethnicity
# 0                White/British
# 1                   Not Stated
# 2                White/British
# 3                White/British
# 4                White/British
# ...                        ...
# 4295837          White/British
# 4295838          White/British
# 4295839          White/British
# 4295840          White - Irish
# 4295841          White/British
#
# [4295842 rows x 14 columns]

# %%
df['Date'] = df['Date'].str.slice(0, 16)
df['Date'] = pd.to_datetime(df['Date'], format = "%Y-%m-%d %H:%M")

df.set_index('Date', inplace=True)

display(df)
# Out:
#                               Type   Latitude  Longitude Gender Age range  \
# Date
# 2014-09-30 23:35:00  Person search  51.718631  -3.059401    NaN     25-34
# 2014-09-30 23:50:00  Person search  51.583966  -2.994404   Male   over 34
# 2014-10-01 00:20:00  Person search  51.731833  -3.066993   Male   over 34
# 2014-10-01 01:15:00  Person search  51.824979  -3.018959   Male   over 34
# 2014-10-01 08:20:00  Person search  51.591295  -2.987910   Male     25-34
# ...                            ...        ...        ...    ...       ...
# 2024-11-30 21:26:00  Person search  52.376361  -1.747030   Male     10-17
# 2024-11-30 21:40:00  Person search  52.371651  -1.752065   Male     10-17
# 2024-11-30 21:56:00  Person search  52.371651  -1.752065   Male     10-17
# 2024-11-30 22:06:00  Person search  52.371651  -1.752065   Male     10-17
# 2024-11-30 22:22:00  Person search  52.599007  -2.062349   Male     25-34
#
#                     Officer-defined ethnicity  \
# Date
# 2014-09-30 23:35:00                     Other
# 2014-09-30 23:50:00                     Other
# 2014-10-01 00:20:00                     White
# 2014-10-01 01:15:00                     White
# 2014-10-01 08:20:00                     White
# ...                                       ...
# 2024-11-30 21:26:00                     White
# 2024-11-30 21:40:00                     White
# 2024-11-30 21:56:00                     White
# 2024-11-30 22:06:00                     White
# 2024-11-30 22:22:00                     White
#
#                                                            Legislation  \
# Date
# 2014-09-30 23:35:00  Police and Criminal Evidence Act 1984 (section 1)
# 2014-09-30 23:50:00              Misuse of Drugs Act 1971 (section 23)
# 2014-10-01 00:20:00  Police and Criminal Evidence Act 1984 (section 1)
# 2014-10-01 01:15:00  Police and Criminal Evidence Act 1984 (section 1)
# 2014-10-01 08:20:00              Misuse of Drugs Act 1971 (section 23)
# ...                                                                ...
# 2024-11-30 21:26:00  Police and Criminal Evidence Act 1984 (section 1)
# 2024-11-30 21:40:00  Police and Criminal Evidence Act 1984 (section 1)
# 2024-11-30 21:56:00  Police and Criminal Evidence Act 1984 (section 1)
# 2024-11-30 22:06:00  Police and Criminal Evidence Act 1984 (section 1)
# 2024-11-30 22:22:00  Police and Criminal Evidence Act 1984 (section 1)
#
#                              Object of search  \
# Date
# 2014-09-30 23:35:00              Stolen goods
# 2014-09-30 23:50:00          Controlled drugs
# 2014-10-01 00:20:00          Controlled drugs
# 2014-10-01 01:15:00              Stolen goods
# 2014-10-01 08:20:00          Controlled drugs
# ...                                       ...
# 2024-11-30 21:26:00         Offensive weapons
# 2024-11-30 21:40:00         Offensive weapons
# 2024-11-30 21:56:00         Offensive weapons
# 2024-11-30 22:06:00         Offensive weapons
# 2024-11-30 22:22:00  Article for use in theft
#
#                                                Outcome  \
# Date
# 2014-09-30 23:35:00  Nothing found - no further action
# 2014-09-30 23:50:00  Nothing found - no further action
# 2014-10-01 00:20:00  Nothing found - no further action
# 2014-10-01 01:15:00  Nothing found - no further action
# 2014-10-01 08:20:00                                NaN
# ...                                                ...
# 2024-11-30 21:26:00       A no further action disposal
# 2024-11-30 21:40:00       A no further action disposal
# 2024-11-30 21:56:00       A no further action disposal
# 2024-11-30 22:06:00       A no further action disposal
# 2024-11-30 22:22:00               Community resolution
#
#                     Outcome linked to object of search  \
# Date
# 2014-09-30 23:35:00                                NaN
# 2014-09-30 23:50:00                                NaN
# 2014-10-01 00:20:00                                NaN
# 2014-10-01 01:15:00                                NaN
# 2014-10-01 08:20:00                                NaN
# ...                                                ...
# 2024-11-30 21:26:00                                NaN
# 2024-11-30 21:40:00                                NaN
# 2024-11-30 21:56:00                                NaN
# 2024-11-30 22:06:00                                NaN
# 2024-11-30 22:22:00                                NaN
#
#                     Removal of more than just outer clothing    Police_Dept  \
# Date
# 2014-09-30 23:35:00                                      NaN          gwent
# 2014-09-30 23:50:00                                      NaN          gwent
# 2014-10-01 00:20:00                                      NaN          gwent
# 2014-10-01 01:15:00                                      NaN          gwent
# 2014-10-01 08:20:00                                      NaN          gwent
# ...                                                      ...            ...
# 2024-11-30 21:26:00                                    False  west_midlands
# 2024-11-30 21:40:00                                    False  west_midlands
# 2024-11-30 21:56:00                                    False  west_midlands
# 2024-11-30 22:06:00                                    False  west_midlands
# 2024-11-30 22:22:00                                    False  west_midlands
#
#                     Self_defined_ethnicity
# Date
# 2014-09-30 23:35:00          White/British
# 2014-09-30 23:50:00             Not Stated
# 2014-10-01 00:20:00          White/British
# 2014-10-01 01:15:00          White/British
# 2014-10-01 08:20:00          White/British
# ...                                    ...
# 2024-11-30 21:26:00          White/British
# 2024-11-30 21:40:00          White/British
# 2024-11-30 21:56:00          White/British
# 2024-11-30 22:06:00          White - Irish
# 2024-11-30 22:22:00          White/British
#
# [4295842 rows x 13 columns]

# %% [markdown]
# # Visualise the Data

# %% [markdown]
# ## National Lockdowns

# %%
# Assume lockdown periods in the UK (adjust dates as necessary)
lockdown_periods = [
    ('2020-03-23', '2020-06-01'),  # First lockdown
    ('2020-09-05', '2020-11-02'),  # Second lockdown
    ('2021-01-06', '2021-07-01')   # Third lockdown
]

# Resample data to weekly counts
daily_counts = df.resample('ME').size()

# Plot the data
plt.figure(figsize=(12, 6))
plt.plot(daily_counts, label="Weekly Stops and Searches")

# Highlight lockdown periods
for start, end in lockdown_periods:
    plt.axvspan(pd.to_datetime(start), pd.to_datetime(end), alpha=0.3, label="Covid-19 Lockdown", color='red')

# Add labels, title, and legend
plt.title("Occurrences of Stops and Searches Over Time (With Lockdowns Highlighted)")
plt.xlabel("Date")
plt.ylabel("Number of Stops/Searches")
plt.legend(loc='upper left')
# plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## By dept.

# %%
plt.figure(figsize=(12, 6))
           
# Resample data to weekly counts
for dept in df.Police_Dept.value_counts().index:
    daily_counts = df[df['Police_Dept'] == dept].resample('ME').size()

    # Plot the data
    plt.plot(daily_counts, label=dept)


# Add labels, title, and legend
plt.title("Stops and Searches Over Time by Police Dept. ")
plt.xlabel("Date")
plt.ylabel("Number of Stops/Searches")
# plt.legend(loc='upper left')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## By Location

# %%
df.resample('YE')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df.resample('YE').index
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\resample.py:215, in Resampler.__getattr__(self, attr)
#     212 if attr in self.obj:
#     213     return self[attr]
# --> 215 return object.__getattribute__(self, attr)
#
# AttributeError: 'DatetimeIndexResampler' object has no attribute 'index'

# %%
df_2020 = df

plt.scatter(df['Longitude'], df['Latitude'], alpha=0.1)
plt.show()

# %%
df['Legislation'].value_counts()
# Out:
# Legislation
# Misuse of Drugs Act 1971 (section 23)                      2570798
# Police and Criminal Evidence Act 1984 (section 1)          1445858
# Criminal Justice and Public Order Act 1994 (section 60)      51427
# Firearms Act 1968 (section 47)                               33908
# Criminal Justice Act 1988 (section 139B)                      9572
# Psychoactive Substances Act 2016 (s36(2))                     3544
# Poaching Prevention Act 1862 (section 2)                      1892
# Customs and Excise Management Act 1979 (section 163)           423
# Police and Criminal Evidence Act 1984 (section 6)              318
# Wildlife and Countryside Act 1981 (section 19)                 298
# Aviation Security Act 1982 (section 27(1))                     284
# Psychoactive Substances Act 2016 (s37(2))                      117
# Deer Act 1991 (section 12)                                      93
# Crossbows Act 1987 (section 4)                                  56
# Public Stores Act 1875 (section 6)                              46
# Environmental Protection Act 1990 (section 34B )                44
# Protection of Badgers Act 1992 (section 11)                     40
# Sporting Events Act 1985 (section 7)                            23
# Hunting Act 2004 (section 8)                                    23
# Conservation of Seals Act 1970 (section 4)                      16
# Psychoactive Substances Act 2016 (s38(2))                        9
# Name: count, dtype: int64

# %%
df_1 = df[df['Legislation'] == 'Misuse of Drugs Act 1971 (section 23)']
df_2 = df[df['Legislation'] == 'Police and Criminal Evidence Act 1984 (section 1)']
df_3= df[df['Legislation'] == 'Criminal Justice and Public Order Act 1994 (section 60)']

# %%
# df_1 = df[df['Legislation'] == 'Misuse of Drugs Act 1971 (section 23)']
# df_2 = df[df['Legislation'] == 'Police and Criminal Evidence Act 1984 (section 1)']
# df_3= df[df['Legislation'] == 'Criminal Justice and Public Order Act 1994 (section 60)']



# adjust 'D' to 'W' for weekly or 'M' for monthly
daily_counts_1 = df_1.resample('W').size()
daily_counts_2 = df_2.resample('W').size()
daily_counts_3 = df_3.resample('W').size()

# Plot the data
plt.figure(figsize=(12, 6))
plt.plot(daily_counts_1, label="1")
plt.plot(daily_counts_2, label="2")
plt.plot(daily_counts_3, label="3")


plt.title("Occurrences of Stops and Searches Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Stops/Searches")
plt.legend()
plt.grid(True)

plt.show()
