# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load in the Data

# %%
df = pd.read_csv('../../data/police_zips/stop_and_search_sep14_nov24.csv', index_col=0)
display(df)
# Out:
#                   Type                       Date   Latitude  Longitude  \
# 0        Person search  2014-09-30T23:35:00+00:00  51.718631  -3.059401
# 1        Person search  2014-09-30T23:50:00+00:00  51.583966  -2.994404
# 2        Person search  2014-10-01T00:20:00+00:00  51.731833  -3.066993
# 3        Person search  2014-10-01T01:15:00+00:00  51.824979  -3.018959
# 4        Person search  2014-10-01T08:20:00+00:00  51.591295  -2.987910
# ...                ...                        ...        ...        ...
# 4295837  Person search  2024-11-30T21:26:00+00:00  52.376361  -1.747030
# 4295838  Person search  2024-11-30T21:40:00+00:00  52.371651  -1.752065
# 4295839  Person search  2024-11-30T21:56:00+00:00  52.371651  -1.752065
# 4295840  Person search  2024-11-30T22:06:00+00:00  52.371651  -1.752065
# 4295841  Person search  2024-11-30T22:22:00+00:00  52.599007  -2.062349
#
#         Gender Age range                             Self-defined ethnicity  \
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Longitude'],df['Latitude'] , s=10, alpha=0.05)
plt.show()

# %% [markdown]
# # Clean the Data

# %%
cols = df.columns
print(cols)
# Out:
# Index(['Type', 'Date', 'Latitude', 'Longitude', 'Gender', 'Age range',
#        'Self-defined ethnicity', 'Officer-defined ethnicity', 'Legislation',
#        'Object of search', 'Outcome', 'Outcome linked to object of search',
#        'Removal of more than just outer clothing', 'Police_Dept'],
#       dtype='object')

# %%
for col in cols:
    
    print(col)
    print(df[col].value_counts())
    print('\n')
# Out:
# Type
# Person search                3329355
# Person and Vehicle search     860514
# Vehicle search                105973
# Name: Type, dtype: int64
#
#
# Date
# 2024-01-31T00:00:00+00:00    762
# 2015-05-23T23:00:00+00:00    463
# 2017-04-10T23:30:00+00:00    362
# 2019-05-30T23:00:00+00:00    257
# 2019-05-29T23:00:00+00:00    219
#                             ...
# 2020-02-19T00:06:31+00:00      1
# 2020-02-18T23:56:22+00:00      1
# 2020-02-18T23:56:08+00:00      1
# 2020-02-18T23:47:23+00:00      1
# 2024-11-30T22:22:00+00:00      1
# Name: Date, Length: 2089954, dtype: int64
#
#
# Latitude
# 51.378427    4936
# 51.404644    3329
# 51.539189    3019
# 51.402747    3008
# 51.515111    2688
#              ...
# 52.376662       1
# 52.349470       1
# 52.332364       1
# 52.696587       1
# 52.599007       1
# Name: Latitude, Length: 401068, dtype: int64
#
#
# Longitude
# -0.102657    4872
# -0.513346    3329
# -0.509813    3008
# -0.142008    2950
# -0.145107    2688
# ...

# %% [markdown]
# # Match Self Defined Ethnicities

# %%
# mapping
category_mapping = {
    "White - English/Welsh/Scottish/Northern Irish/British": "White/British",
    "White - White British (W1)": "White/British",
    "White - Any other White background": "Other White",
    "White - Any other White ethnic background (W9)": "Other White",
    "Black/African/Caribbean/Black British - Any other Black/African/Caribbean background": "Black/Black British - Other",
    "Black/African/Caribbean/Black British - African": "Black/Black British - African",
    "Black/African/Caribbean/Black British - Caribbean": "Black/Black British - Caribbean",
    "Asian/Asian British - Any other Asian background": "Asian/Asian British - other",
    "Black or Black British - Any other Black ethnic background (B9)" : "Black/Black British - Other",
    "Black or Black British - African (B2)" : "Black/Black British - African",
    "Black or Black British - Caribbean (B1)": "Black/Black British - Caribbean",
    "Asian or Asian British - Any other Asian ethnic background (A9)": "Asian/Asian British - other",
    "Asian or Asian British - Pakistani (A2)": "Asian/Asian British - Pakistani",
    "Asian or Asian British - Bangladeshi (A3)": "Asian/Asian British - Bangladeshi",
    "Mixed - White and Black Caribbean (M1)": "Mixed/Multiple ethnic groups - White and Black Caribbean",
    "Mixed - White and Black African (M2)": "Mixed/Multiple ethnic groups - White and Black African",
    "Mixed - White and Asian (M3)": "Mixed/Multiple ethnic groups - White and Asian",
    "Asian or Asian British - Indian (A1)": "Asian/Asian British - Indian",
    "Mixed - Any other Mixed ethnic background (M9)": "Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background",
    "Not Stated (NS)": "Not Stated",
    "Other ethnic group - Not stated": "Not Stated",
    "Chinese or other ethnic group - Chinese (O1)":"Chinese/Other ethnic group",
    "Chinese or other ethnic group - Any other ethnic group (O9)":"Chinese - other",
    "White - White Irish (W2)":"White - Irish",

}

# apply the mapping
df['Self_defined_ethnicity'] = df['Self-defined ethnicity'].replace(category_mapping)
df['Self_defined_ethnicity'].value_counts()
# Out:
# White/British                                                                1885917
# Not Stated                                                                    645107
# Other White                                                                   313336
# Black/Black British - Other                                                   254822
# Black/Black British - African                                                 200783
# Asian/Asian British - other                                                   152000
# Black/Black British - Caribbean                                               151438
# Asian/Asian British - Pakistani                                               124231
# Asian/Asian British - Bangladeshi                                              69351
# Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background      60397
# Other ethnic group - Any other ethnic group                                    55354
# ...

# %% [markdown]
# # Dealing with NaN

# %%
# df['Gender'] = df['Gender'].fillna('Not Stated')



df
# Out:
#                                     Type   Latitude  Longitude Gender  \
# Date
# 2014-09-30 23:35:00+00:00  Person search  51.718631  -3.059401    NaN
# 2014-09-30 23:50:00+00:00  Person search  51.583966  -2.994404   Male
# 2014-10-01 00:20:00+00:00  Person search  51.731833  -3.066993   Male
# 2014-10-01 01:15:00+00:00  Person search  51.824979  -3.018959   Male
# 2014-10-01 08:20:00+00:00  Person search  51.591295  -2.987910   Male
# ...                                  ...        ...        ...    ...
# 2024-11-30 21:26:00+00:00  Person search  52.376361  -1.747030   Male
# 2024-11-30 21:40:00+00:00  Person search  52.371651  -1.752065   Male
# 2024-11-30 21:56:00+00:00  Person search  52.371651  -1.752065   Male
# 2024-11-30 22:06:00+00:00  Person search  52.371651  -1.752065   Male
# 2024-11-30 22:22:00+00:00  Person search  52.599007  -2.062349   Male
#
#                           Age range  \
# Date
# 2014-09-30 23:35:00+00:00     25-34
# 2014-09-30 23:50:00+00:00   over 34
# ...

# %% [markdown]
# # Remove Un-Used Columns

# %%
df = df.drop(columns=['Self-defined ethnicity'])


display(df)
# Out:
#                                     Type   Latitude  Longitude Gender  \
# Date
# 2014-09-30 23:35:00+00:00  Person search  51.718631  -3.059401    NaN
# 2014-09-30 23:50:00+00:00  Person search  51.583966  -2.994404   Male
# 2014-10-01 00:20:00+00:00  Person search  51.731833  -3.066993   Male
# 2014-10-01 01:15:00+00:00  Person search  51.824979  -3.018959   Male
# 2014-10-01 08:20:00+00:00  Person search  51.591295  -2.987910   Male
# ...                                  ...        ...        ...    ...
# 2024-11-30 21:26:00+00:00  Person search  52.376361  -1.747030   Male
# 2024-11-30 21:40:00+00:00  Person search  52.371651  -1.752065   Male
# 2024-11-30 21:56:00+00:00  Person search  52.371651  -1.752065   Male
# 2024-11-30 22:06:00+00:00  Person search  52.371651  -1.752065   Male
# 2024-11-30 22:22:00+00:00  Person search  52.599007  -2.062349   Male
#
#                           Age range Officer-defined ethnicity  \
# Date
# ...

# %% [markdown]
# # Save to CSV

# %%
df.to_csv('../../data/stop_and_search_cleaned.csv')
