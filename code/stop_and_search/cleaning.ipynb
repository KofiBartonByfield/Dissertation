# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/police_zips/stop_and_search_sep14_nov24.csv')
display(df)
# Out:
#          Unnamed: 0           Type                       Date   Latitude  \
# 0                 0  Person search  2014-09-30T23:35:00+00:00  51.718631
# 1                 1  Person search  2014-09-30T23:50:00+00:00  51.583966
# 2                 2  Person search  2014-10-01T00:20:00+00:00  51.731833
# 3                 3  Person search  2014-10-01T01:15:00+00:00  51.824979
# 4                 4  Person search  2014-10-01T08:20:00+00:00  51.591295
# ...             ...            ...                        ...        ...
# 4295837     4295837  Person search  2024-11-30T21:26:00+00:00  52.376361
# 4295838     4295838  Person search  2024-11-30T21:40:00+00:00  52.371651
# 4295839     4295839  Person search  2024-11-30T21:56:00+00:00  52.371651
# 4295840     4295840  Person search  2024-11-30T22:06:00+00:00  52.371651
# 4295841     4295841  Person search  2024-11-30T22:22:00+00:00  52.599007
#
#          Longitude Gender Age range  \
# 0        -3.059401    NaN     25-34
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Longitude'],df['Latitude'] , s=10, alpha=0.1)
plt.show()
