# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/police_zips/stop_and_search_sep14_nov24.csv')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Longitude'],df['Latitude'] , s=10, alpha=0.3)
plt.show()
