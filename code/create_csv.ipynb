# %% [markdown]
# # Creating the London and Merseyside CSVs

# %% [markdown]
# Load in libraries:

# %%
import os
import pandas as pd 
from pyproj import Transformer
import geopandas as gpd

# %% [markdown]
# ### Load the data

# %% [markdown]
# https://data.police.uk/data/

# %%
path = '../data/police_zips'    

# find all csv file paths
csv_names = []
for folder in os.listdir(path):
        
            folder_contents = os.listdir(f'{path}/{folder}')
            
            for file in folder_contents:
                
                    
                csv_names.append(f'{path}/{folder}/{file}')



print(f'There are {len(csv_names)} different CSVs')
# Out:
# There are 108 different CSVs

# %% [markdown]
# ### Extract the CSV's

# %%
crimes, outcomes, stops = [], [], []

# loop through the csvs
for csv in csv_names:
    
    if "stop-and-search.csv" in csv:
        stops.append(pd.read_csv(csv))


    elif "street.csv" in csv:
        crimes.append(pd.read_csv(csv))

    elif "outcomes.csv" in csv:
        outcomes.append(pd.read_csv(csv))


outcomes_df = pd.concat(outcomes, ignore_index=True)
crimes_df = pd.concat(crimes, ignore_index=True)
stops_df = pd.concat(stops, ignore_index=True)

# %% [markdown]
# ### Combine the crime and outcomes by 'CRIME ID'

# %%
crimes_df = crimes_df.merge(outcomes_df[['Crime ID', 'Outcome type']] , on='Crime ID', how='left')
crimes_df
# Out:
#                                                   Crime ID    Month  \
# 0        f344b946a36b4dc1db0a4bb889e8ec0fd23ab65aa2bf39...  2022-01
# 1        e74962917ce995fa9e52623b6fe0c218619b79d4a22550...  2022-01
# 2        067092d6822753127ce767d011ea5c5b4375de6f5a3c48...  2022-01
# 3                                                      NaN  2022-01
# 4                                                      NaN  2022-01
# ...                                                    ...      ...
# 1360391  7b127e4ff2fd1fdd40db3230cb20fac5af55b7cc66e2b9...  2022-12
# 1360392  5160c9abc5f0674f5f047e69c26f49f50f61f6e322131d...  2022-12
# 1360393  cee8aad8bb809fc0daefafd0d2fcece46fb554940212d0...  2022-12
# 1360394  8f12b9f524fc5c8ec0e3965f7d7ab406632a2b3549aa12...  2022-12
# 1360395  106dcbf7579082c309a6a01d4f95c6ea4fb9b7ddb3ee93...  2022-12
#
#                          Reported by                 Falls within  Longitude  \
# 0              City of London Police        City of London Police  -0.106453
# 1              City of London Police        City of London Police  -0.113256
# 2              City of London Police        City of London Police  -0.116100
# 3              City of London Police        City of London Police  -0.097601
# 4              City of London Police        City of London Police  -0.095914
# ...                              ...                          ...        ...
# 1360391  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1360392  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1360393  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1360394  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1360395  Metropolitan Police Service  Metropolitan Police Service        NaN
#
#           Latitude                        Location  LSOA code  \
# 0        51.518207  On or near Charterhouse Street  E01000916
# 1        51.516824           On or near Old Square  E01000914
# 2        51.518470          On or near Supermarket  E01000914
# 3        51.520699    On or near Carthusian Street  E01000001
# 4        51.520348         On or near Beech Street  E01000001
# ...            ...                             ...        ...
# 1360391        NaN                     No Location        NaN
# 1360392        NaN                     No Location        NaN
# 1360393        NaN                     No Location        NaN
# 1360394        NaN                     No Location        NaN
# 1360395        NaN                     No Location        NaN
#
#                    LSOA name             Crime type  \
# 0                Camden 027B               Burglary
# 1                Camden 028B            Other theft
# 2                Camden 028B            Other theft
# 3        City of London 001A  Anti-social behaviour
# 4        City of London 001A  Anti-social behaviour
# ...                      ...                    ...
# 1360391                  NaN            Other crime
# 1360392                  NaN            Other crime
# 1360393                  NaN            Other crime
# 1360394                  NaN            Other crime
# 1360395                  NaN            Other crime
#
#                                  Last outcome category  Context  \
# 0                            Status update unavailable      NaN
# 1        Investigation complete; no suspect identified      NaN
# 2                            Status update unavailable      NaN
# 3                                                  NaN      NaN
# 4                                                  NaN      NaN
# ...                                                ...      ...
# 1360391  Investigation complete; no suspect identified      NaN
# 1360392  Investigation complete; no suspect identified      NaN
# 1360393                       Offender given a caution      NaN
# 1360394                      Status update unavailable      NaN
# 1360395  Investigation complete; no suspect identified      NaN
#
#                                           Outcome type
# 0                                                  NaN
# 1        Investigation complete; no suspect identified
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 1360391                                            NaN
# 1360392                                            NaN
# 1360393                       Offender given a caution
# 1360394                                            NaN
# 1360395                                            NaN
#
# [1360396 rows x 13 columns]

# %% [markdown]
# ### Convert to datetime

# %%
crimes_df['Date'] = pd.to_datetime(crimes_df['Month'], format= '%Y-%m')
stops_df['Date'] = pd.to_datetime(stops_df['Date']).dt.tz_convert(None) # convert to datetime and remove timezone
stops_df.drop(columns=['Part of a policing operation', 'Policing operation'], inplace=True) # remove empty columns
stops_df
# Out:
#                              Type                Date   Latitude  Longitude  \
# 0                   Person search 2022-01-01 01:14:23  51.506255  -0.074901
# 1                   Person search 2022-01-01 01:20:32  51.506255  -0.074901
# 2                   Person search 2022-01-01 01:28:56  51.506255  -0.074901
# 3                   Person search 2022-01-01 01:48:59  51.508066  -0.087780
# 4                   Person search 2022-01-01 02:49:39  51.517680  -0.078484
# ...                           ...                 ...        ...        ...
# 235906  Person and Vehicle search 2022-12-17 21:35:00  51.631560  -0.195095
# 235907              Person search 2022-12-17 21:57:00        NaN        NaN
# 235908              Person search 2022-12-17 22:00:00  51.514365  -0.143408
# 235909              Person search 2022-12-17 22:16:00        NaN        NaN
# 235910              Person search 2022-12-17 23:40:00  51.460388  -0.057168
#
#         Gender Age range                             Self-defined ethnicity  \
# 0         Male     10-17                    Other ethnic group - Not stated
# 1         Male     10-17                    Other ethnic group - Not stated
# 2         Male     10-17                  Asian/Asian British - Bangladeshi
# 3         Male       NaN                                                NaN
# 4         Male     18-24  White - English/Welsh/Scottish/Northern Irish/...
# ...        ...       ...                                                ...
# 235906    Male     25-34   Asian/Asian British - Any other Asian background
# 235907    Male     25-34                    Other ethnic group - Not stated
# 235908  Female   over 34                 White - Any other White background
# 235909    Male     10-17  Black/African/Caribbean/Black British - Caribbean
# 235910    Male   over 34                    Other ethnic group - Not stated
#
#        Officer-defined ethnicity  \
# 0                          Asian
# 1                          Asian
# 2                          Asian
# 3                            NaN
# 4                          White
# ...                          ...
# 235906                     Asian
# 235907                     White
# 235908                     White
# 235909                     Black
# 235910                     Black
#
#                                               Legislation   Object of search  \
# 0       Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 1       Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 2       Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 3       Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 4       Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# ...                                                   ...                ...
# 235906              Misuse of Drugs Act 1971 (section 23)   Controlled drugs
# 235907  Police and Criminal Evidence Act 1984 (section 1)       Stolen goods
# 235908  Police and Criminal Evidence Act 1984 (section 1)       Stolen goods
# 235909  Police and Criminal Evidence Act 1984 (section 1)       Stolen goods
# 235910              Misuse of Drugs Act 1971 (section 23)   Controlled drugs
#
#                              Outcome Outcome linked to object of search  \
# 0       A no further action disposal                              False
# 1       A no further action disposal                              False
# 2       A no further action disposal                              False
# 3       A no further action disposal                              False
# 4       A no further action disposal                              False
# ...                              ...                                ...
# 235906  A no further action disposal                                NaN
# 235907          Community resolution                                NaN
# 235908  A no further action disposal                                NaN
# 235909  A no further action disposal                                NaN
# 235910  A no further action disposal                                NaN
#
#        Removal of more than just outer clothing
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 235906                                      NaN
# 235907                                      NaN
# 235908                                      NaN
# 235909                                      NaN
# 235910                                      NaN
#
# [235911 rows x 13 columns]

# %% [markdown]
# ## Map LSOA to coords

# %%
LSOA_df = pd.read_csv('../data/mapping_csvs/LSOA_to_coords.csv')

# Define transformer from OSGB36 (EPSG:27700) to WGS84 (EPSG:4326)
transformer = Transformer.from_crs("EPSG:27700", "EPSG:4326", always_xy=True)

def convert_uk_coords(eastings, northings):
    """Vectorised function to convert Eastings/Northings to Longitude/Latitude."""
    longitudes, latitudes = transformer.transform(eastings, northings)
    return longitudes, latitudes



# Example DataFrame
LSOA_df['Longitude'], LSOA_df['Latitude'] = convert_uk_coords(LSOA_df['x'], LSOA_df['y'])


LSOA_df = LSOA_df[['LSOA01CD', 'Longitude', 'Latitude']]
LSOA_df
# Out:
#         LSOA01CD  Longitude   Latitude
# 0      E01000001  -0.096266  51.519526
# 1      E01000002  -0.092626  51.519692
# 2      E01000003  -0.095916  51.522029
# 3      E01000004  -0.097571  51.514134
# 4      E01000005  -0.074945  51.513756
# ...          ...        ...        ...
# 34373  W01001892  -3.210109  51.507316
# 34374  W01001893  -3.248157  51.532365
# 34375  W01001894  -3.231427  51.522516
# 34376  W01001895  -3.231117  51.517978
# 34377  W01001896  -3.222176  51.517235
#
# [34378 rows x 3 columns]

# %% [markdown]
# ### Geo map the LSOA codes

# %%
# Convert crime DataFrames to GeoDataFrames
gdf_ss = gpd.GeoDataFrame(stops_df, 
                            geometry=gpd.points_from_xy(stops_df['Longitude'], 
                                                        stops_df['Latitude']),
                            crs="EPSG:4326")  # WGS84 (standard lat/lon)

# Convert LSOA DataFrame to GeoDataFrame
gdf_lsoa = gpd.GeoDataFrame(LSOA_df, 
                            geometry=gpd.points_from_xy(LSOA_df['Longitude'], 
                                                        LSOA_df['Latitude']),
                            crs="EPSG:4326")

# Reproject to British National Grid (EPSG:27700) for accurate distance calculations
gdf_ss = gdf_ss.to_crs("EPSG:27700")
gdf_lsoa = gdf_lsoa.to_crs("EPSG:27700")

# Perform spatial join with corrected CRS
stops_df = gpd.sjoin_nearest(gdf_ss, gdf_lsoa, how="left", distance_col="distance")


# Convert back to EPSG:4326 (optional, if needed for mapping or output)
stops_df = stops_df.to_crs('EPSG:4326')

# Drop unnecessary columns if they exist
cols_to_drop = ['geometry', 'Longitude_right', 'Latitude_right']
stops_df = stops_df.drop(columns=[col for col in cols_to_drop if col in stops_df.columns])

# Rename columns to maintain consistency
stops_df = stops_df.rename(columns={'LSOA01CD': 'LSOA code',
                                          'Latitude_left': 'Latitude',
                                          'Longitude_left': 'Longitude'})

display(stops_df)
# Out:
#                              Type                Date   Latitude  Longitude  \
# 0                   Person search 2022-01-01 01:14:23  51.506255  -0.074901
# 1                   Person search 2022-01-01 01:20:32  51.506255  -0.074901
# 2                   Person search 2022-01-01 01:28:56  51.506255  -0.074901
# 3                   Person search 2022-01-01 01:48:59  51.508066  -0.087780
# 4                   Person search 2022-01-01 02:49:39  51.517680  -0.078484
# ...                           ...                 ...        ...        ...
# 235906  Person and Vehicle search 2022-12-17 21:35:00  51.631560  -0.195095
# 235907              Person search 2022-12-17 21:57:00        NaN        NaN
# 235908              Person search 2022-12-17 22:00:00  51.514365  -0.143408
# 235909              Person search 2022-12-17 22:16:00        NaN        NaN
# 235910              Person search 2022-12-17 23:40:00  51.460388  -0.057168
#
#         Gender Age range                             Self-defined ethnicity  \
# 0         Male     10-17                    Other ethnic group - Not stated
# 1         Male     10-17                    Other ethnic group - Not stated
# 2         Male     10-17                  Asian/Asian British - Bangladeshi
# 3         Male       NaN                                                NaN
# 4         Male     18-24  White - English/Welsh/Scottish/Northern Irish/...
# ...        ...       ...                                                ...
# 235906    Male     25-34   Asian/Asian British - Any other Asian background
# 235907    Male     25-34                    Other ethnic group - Not stated
# 235908  Female   over 34                 White - Any other White background
# 235909    Male     10-17  Black/African/Caribbean/Black British - Caribbean
# 235910    Male   over 34                    Other ethnic group - Not stated
#
#        Officer-defined ethnicity  \
# 0                          Asian
# 1                          Asian
# 2                          Asian
# 3                            NaN
# 4                          White
# ...                          ...
# 235906                     Asian
# 235907                     White
# 235908                     White
# 235909                     Black
# 235910                     Black
#
#                                               Legislation   Object of search  \
# 0       Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 1       Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 2       Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 3       Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 4       Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# ...                                                   ...                ...
# 235906              Misuse of Drugs Act 1971 (section 23)   Controlled drugs
# 235907  Police and Criminal Evidence Act 1984 (section 1)       Stolen goods
# 235908  Police and Criminal Evidence Act 1984 (section 1)       Stolen goods
# 235909  Police and Criminal Evidence Act 1984 (section 1)       Stolen goods
# 235910              Misuse of Drugs Act 1971 (section 23)   Controlled drugs
#
#                              Outcome Outcome linked to object of search  \
# 0       A no further action disposal                              False
# 1       A no further action disposal                              False
# 2       A no further action disposal                              False
# 3       A no further action disposal                              False
# 4       A no further action disposal                              False
# ...                              ...                                ...
# 235906  A no further action disposal                                NaN
# 235907          Community resolution                                NaN
# 235908  A no further action disposal                                NaN
# 235909  A no further action disposal                                NaN
# 235910  A no further action disposal                                NaN
#
#        Removal of more than just outer clothing  index_right  LSOA code  \
# 0                                         False       4024.0  E01004025
# 1                                         False       4024.0  E01004025
# 2                                         False       4024.0  E01004025
# 3                                         False       3934.0  E01003935
# 4                                         False       4309.0  E01004310
# ...                                         ...          ...        ...
# 235906                                      NaN        278.0  E01000279
# 235907                                      NaN          NaN        NaN
# 235908                                      NaN       4763.0  E01004764
# 235909                                      NaN          NaN        NaN
# 235910                                      NaN       4019.0  E01004020
#
#           distance
# 0       414.636814
# 1       414.636814
# 2       414.636814
# 3       566.702621
# 4       319.655331
# ...            ...
# 235906  463.259019
# 235907         NaN
# 235908  400.351140
# 235909         NaN
# 235910  123.867028
#
# [235911 rows x 16 columns]

# %% [markdown]
# ## Clean dual jurisdiction cases

# %% [markdown]
# And add missing LSOAs with no stop and search data

# %% [markdown]
# https://geoportal.statistics.gov.uk/datasets/ons::lsoa-2021-to-local-authority-districts-april-2023-best-fit-lookup-in-ew/explore

# %%
LSOA_names = pd.read_csv('../data/mapping_csvs/LSOA_names.csv')

# Define a list of Merseyside boroughs 
#https://www.ons.gov.uk/visualisations/areas/E11000002/ 
merseyside_names = ['Liverpool', 'Wirral', 'Sefton', 'Knowsley', 'St. Helens']




# Define a list of London boroughs 
# https://www.ons.gov.uk/visualisations/areas/E12000007/
london_boroughs = [
    "Barking and Dagenham", "Barnet", "Bexley", "Brent", "Bromley", "Camden",
    "Croydon", "Ealing", "Enfield", "Greenwich", "Hackney", "Hammersmith and Fulham",
    "Haringey", "Harrow", "Havering", "Hillingdon", "Hounslow", "Islington",
    "Kensington and Chelsea", "Kingston upon Thames", "Lambeth", "Lewisham",
    "Merton", "Newham", "Redbridge", "Richmond upon Thames", "Southwark",
    "Sutton", "Tower Hamlets", "Waltham Forest", "Wandsworth", "Westminster",
    "City of London" 
]

# filter certain boroughs
london_LSOAs = LSOA_names[LSOA_names['LAD23NM'].isin(london_boroughs)]
merseyside_LSOAs = LSOA_names[LSOA_names['LAD23NM'].isin(merseyside_names)]

# sort only LSOA and Borough columns
merseyside_LSOAs = merseyside_LSOAs[['LSOA21CD', 'LAD23NM']]
london_LSOAs = london_LSOAs[['LSOA21CD', 'LAD23NM']]

# change column names
london_LSOAs.columns = ['LSOA code', 'Borough']
merseyside_LSOAs.columns = ['LSOA code', 'Borough']


# # use merge to filter out bad cases
# merseyside = stops_df.merge(merseyside_LSOAs, on='LSOA code', how='right')
# london = stops_df.merge(london_LSOAs, on='LSOA code', how='right')
merseyside = stops_df.merge(merseyside_LSOAs, on='LSOA code', how='right')
london = stops_df.merge(london_LSOAs, on='LSOA code', how='right')

# # Display results
display(merseyside, london)
# Out:
#                             Type                Date   Latitude  Longitude  \
# 0      Person and Vehicle search 2022-01-16 16:57:20  53.476675  -2.875641
# 1                  Person search 2022-01-17 02:03:41  53.476675  -2.875641
# 2                  Person search 2022-01-19 18:37:52  53.475239  -2.867928
# 3                  Person search 2022-01-25 11:48:55  53.474090  -2.877502
# 4                  Person search 2022-01-31 11:23:07  53.474593  -2.876307
# ...                          ...                 ...        ...        ...
# 37780                        NaN                 NaT        NaN        NaN
# 37781                        NaN                 NaT        NaN        NaN
# 37782                        NaN                 NaT        NaN        NaN
# 37783                        NaN                 NaT        NaN        NaN
# 37784                        NaN                 NaT        NaN        NaN
#
#       Gender Age range                             Self-defined ethnicity  \
# 0       Male     18-24  Mixed/Multiple ethnic groups - Any other Mixed...
# 1       Male     25-34  White - English/Welsh/Scottish/Northern Irish/...
# 2       Male   over 34  White - English/Welsh/Scottish/Northern Irish/...
# 3       Male     10-17  White - English/Welsh/Scottish/Northern Irish/...
# 4       Male     25-34   Asian/Asian British - Any other Asian background
# ...      ...       ...                                                ...
# 37780    NaN       NaN                                                NaN
# 37781    NaN       NaN                                                NaN
# 37782    NaN       NaN                                                NaN
# 37783    NaN       NaN                                                NaN
# 37784    NaN       NaN                                                NaN
#
#       Officer-defined ethnicity  \
# 0                         Black
# 1                         White
# 2                         White
# 3                         White
# 4                         Asian
# ...                         ...
# 37780                       NaN
# 37781                       NaN
# 37782                       NaN
# 37783                       NaN
# 37784                       NaN
#
#                                              Legislation  \
# 0      Police and Criminal Evidence Act 1984 (section 1)
# 1      Police and Criminal Evidence Act 1984 (section 1)
# 2      Police and Criminal Evidence Act 1984 (section 1)
# 3                  Misuse of Drugs Act 1971 (section 23)
# 4      Police and Criminal Evidence Act 1984 (section 1)
# ...                                                  ...
# 37780                                                NaN
# 37781                                                NaN
# 37782                                                NaN
# 37783                                                NaN
# 37784                                                NaN
#
#                Object of search                       Outcome  \
# 0      Article for use in theft  A no further action disposal
# 1              Controlled drugs  A no further action disposal
# 2      Article for use in theft  A no further action disposal
# 3              Controlled drugs  A no further action disposal
# 4                  Stolen goods  A no further action disposal
# ...                         ...                           ...
# 37780                       NaN                           NaN
# 37781                       NaN                           NaN
# 37782                       NaN                           NaN
# 37783                       NaN                           NaN
# 37784                       NaN                           NaN
#
#       Outcome linked to object of search  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 37780                                NaN
# 37781                                NaN
# 37782                                NaN
# 37783                                NaN
# 37784                                NaN
#
#       Removal of more than just outer clothing  index_right  LSOA code  \
# 0                                        False       6433.0  E01006434
# 1                                        False       6433.0  E01006434
# 2                                        False       6433.0  E01006434
# 3                                        False       6433.0  E01006434
# 4                                        False       6433.0  E01006434
# ...                                        ...          ...        ...
# 37780                                      NaN          NaN  E01034836
# 37781                                      NaN          NaN  E01034837
# 37782                                      NaN          NaN  E01034838
# 37783                                      NaN          NaN  E01034839
# 37784                                      NaN          NaN  E01034840
#
#          distance   Borough
# 0      171.438495  Knowsley
# 1      171.438495  Knowsley
# 2      454.001372  Knowsley
# 3      221.084998  Knowsley
# 4      124.013202  Knowsley
# ...           ...       ...
# 37780         NaN    Wirral
# 37781         NaN    Wirral
# 37782         NaN    Wirral
# 37783         NaN    Wirral
# 37784         NaN    Wirral
#
# [37785 rows x 17 columns]
#                  Type                Date   Latitude  Longitude Gender  \
# 0       Person search 2022-01-10 02:40:15  51.520699  -0.097601   Male
# 1       Person search 2022-01-10 12:37:39  51.518864  -0.097562   Male
# 2       Person search 2022-01-20 05:14:39  51.520206  -0.097736   Male
# 3       Person search 2022-01-26 08:17:00  51.519703  -0.101649   Male
# 4       Person search 2022-02-04 08:59:46  51.517146  -0.098642   Male
# ...               ...                 ...        ...        ...    ...
# 140289  Person search 2022-12-16 20:20:00  51.485949  -0.141768   Male
# 140290  Person search 2022-12-16 20:20:00  51.485949  -0.141768   Male
# 140291  Person search 2022-12-16 20:20:00  51.485949  -0.141768   Male
# 140292  Person search 2022-12-16 20:25:00  51.485949  -0.141768   Male
# 140293  Person search 2022-12-16 20:25:00  51.485949  -0.141768   Male
#
#        Age range                             Self-defined ethnicity  \
# 0        over 34                    Other ethnic group - Not stated
# 1        over 34  Mixed/Multiple ethnic groups - White and Black...
# 2          10-17  White - English/Welsh/Scottish/Northern Irish/...
# 3          18-24  White - English/Welsh/Scottish/Northern Irish/...
# 4          18-24  Black/African/Caribbean/Black British - Caribbean
# ...          ...                                                ...
# 140289     18-24        Other ethnic group - Any other ethnic group
# 140290     18-24   Asian/Asian British - Any other Asian background
# 140291     18-24        Other ethnic group - Any other ethnic group
# 140292     18-24                 White - Any other White background
# 140293     18-24                    Other ethnic group - Not stated
#
#        Officer-defined ethnicity  \
# 0                          Black
# 1                          Black
# 2                          White
# 3                          White
# 4                          Black
# ...                          ...
# 140289                     Other
# 140290                     Asian
# 140291                     Other
# 140292                     White
# 140293                     Other
#
#                                               Legislation  \
# 0       Police and Criminal Evidence Act 1984 (section 1)
# 1       Police and Criminal Evidence Act 1984 (section 1)
# 2       Police and Criminal Evidence Act 1984 (section 1)
# 3       Police and Criminal Evidence Act 1984 (section 1)
# 4       Police and Criminal Evidence Act 1984 (section 1)
# ...                                                   ...
# 140289              Misuse of Drugs Act 1971 (section 23)
# 140290              Misuse of Drugs Act 1971 (section 23)
# 140291              Misuse of Drugs Act 1971 (section 23)
# 140292              Misuse of Drugs Act 1971 (section 23)
# 140293              Misuse of Drugs Act 1971 (section 23)
#
#                 Object of search                       Outcome  \
# 0                   Stolen goods  A no further action disposal
# 1       Article for use in theft                        Arrest
# 2       Article for use in theft  A no further action disposal
# 3                   Stolen goods          Community resolution
# 4                   Stolen goods  A no further action disposal
# ...                          ...                           ...
# 140289          Controlled drugs          Community resolution
# 140290          Controlled drugs          Community resolution
# 140291          Controlled drugs          Community resolution
# 140292          Controlled drugs          Community resolution
# 140293          Controlled drugs          Community resolution
#
#        Outcome linked to object of search  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                     NaN
# 4                                   False
# ...                                   ...
# 140289                                NaN
# 140290                                NaN
# 140291                                NaN
# 140292                                NaN
# 140293                                NaN
#
#        Removal of more than just outer clothing  index_right  LSOA code  \
# 0                                         False          0.0  E01000001
# 1                                         False          0.0  E01000001
# 2                                         False          0.0  E01000001
# 3                                           NaN          0.0  E01000001
# 4                                         False          0.0  E01000001
# ...                                         ...          ...        ...
# 140289                                      NaN       4664.0  E01004665
# 140290                                      NaN       4664.0  E01004665
# 140291                                      NaN       4664.0  E01004665
# 140292                                      NaN       4664.0  E01004665
# 140293                                      NaN       4664.0  E01004665
#
#           distance         Borough
# 0       160.042424  City of London
# 1       116.270257  City of London
# 2       127.020561  City of London
# 3       374.125238  City of London
# 4       311.926748  City of London
# ...            ...             ...
# 140289   55.143696     Westminster
# 140290   55.143696     Westminster
# 140291   55.143696     Westminster
# 140292   55.143696     Westminster
# 140293   55.143696     Westminster
#
# [140294 rows x 17 columns]

# %% [markdown]
# # Creating LSOA Statistics

# %% [markdown]
# ## House Prices

# %% [markdown]
# https://www.ons.gov.uk/peoplepopulationandcommunity/housing/datasets/meanpricepaidbylowerlayersuperoutputareahpssadataset47

# %%
# Read the 5th sheet (index 4, since indexing starts from 0)
xls = pd.read_excel('../data/LSOA_data/LSOA_house_prices.xls', 
                    sheet_name=5, 
                    engine='xlrd')

headings = xls.iloc[4]
house_prices = xls.iloc[5:]

# headings
house_prices.columns = headings

house_prices = house_prices[['Local authority code','LSOA code', 
                             'Year ending Jun 2022', 'Year ending Sep 2022', 'Year ending Dec 2022']]


house_prices['mean_house_price'] = (
    house_prices.iloc[:, 2:]
    .apply(pd.to_numeric, errors='coerce')  # Convert non-numeric values to NaN
    .mean(axis=1)
    .round()
)

house_prices = house_prices[['LSOA code', 'mean_house_price']].reset_index()
house_prices
# Out:
# 4      index  LSOA code  mean_house_price
# 0          5  E01011949          100415.0
# 1          6  E01011950           55639.0
# 2          7  E01011951           71779.0
# 3          8  E01011952           77052.0
# 4          9  E01011953           95933.0
# ...      ...        ...               ...
# 34748  34753  W01001320          187601.0
# 34749  34754  W01001321          128623.0
# 34750  34755  W01001322          162018.0
# 34751  34756  W01001324          179577.0
# 34752  34757  W01001898          215486.0
#
# [34753 rows x 3 columns]

# %%
# Merge house prices data with the merseyside DataFrame
merseyside = house_prices.merge(merseyside, on='LSOA code', how='right')
london = house_prices.merge(london, on='LSOA code', how='right')

# Calculate the mean of 'mean_house_price'
m_mean = merseyside['mean_house_price'].mean()
l_mean = london['mean_house_price'].mean()

# Fill missing values with the mean house price
merseyside['mean_house_price'] = merseyside['mean_house_price'].fillna(m_mean)
london['mean_house_price'] = london['mean_house_price'].fillna(l_mean) # change the value of parliament to BIG!!!!!

# %% [markdown]
# ### Fix City of London House Prices

# %% [markdown]
# https://www.ons.gov.uk/visualisations/housingpriceslocal/E09000033/

# %%
CoL_LSAOs = LSOA_names[LSOA_names['LAD23NM'].isin(["City of London"])][['LSOA21CD']]

for place in CoL_LSAOs.values:

    london.loc[london['LSOA code'].isin(place), 'mean_house_price'] = 11_100_000

london
# Out:
#           index  LSOA code  mean_house_price           Type  \
# 0       28014.0  E01000001      1.110000e+07  Person search
# 1       28014.0  E01000001      1.110000e+07  Person search
# 2       28014.0  E01000001      1.110000e+07  Person search
# 3       28014.0  E01000001      1.110000e+07  Person search
# 4       28014.0  E01000001      1.110000e+07  Person search
# ...         ...        ...               ...            ...
# 140289  32738.0  E01004665      7.260344e+05  Person search
# 140290  32738.0  E01004665      7.260344e+05  Person search
# 140291  32738.0  E01004665      7.260344e+05  Person search
# 140292  32738.0  E01004665      7.260344e+05  Person search
# 140293  32738.0  E01004665      7.260344e+05  Person search
#
#                       Date   Latitude  Longitude Gender Age range  \
# 0      2022-01-10 02:40:15  51.520699  -0.097601   Male   over 34
# 1      2022-01-10 12:37:39  51.518864  -0.097562   Male   over 34
# 2      2022-01-20 05:14:39  51.520206  -0.097736   Male     10-17
# 3      2022-01-26 08:17:00  51.519703  -0.101649   Male     18-24
# 4      2022-02-04 08:59:46  51.517146  -0.098642   Male     18-24
# ...                    ...        ...        ...    ...       ...
# 140289 2022-12-16 20:20:00  51.485949  -0.141768   Male     18-24
# 140290 2022-12-16 20:20:00  51.485949  -0.141768   Male     18-24
# 140291 2022-12-16 20:20:00  51.485949  -0.141768   Male     18-24
# 140292 2022-12-16 20:25:00  51.485949  -0.141768   Male     18-24
# 140293 2022-12-16 20:25:00  51.485949  -0.141768   Male     18-24
#
#                                    Self-defined ethnicity  \
# 0                         Other ethnic group - Not stated
# 1       Mixed/Multiple ethnic groups - White and Black...
# 2       White - English/Welsh/Scottish/Northern Irish/...
# 3       White - English/Welsh/Scottish/Northern Irish/...
# 4       Black/African/Caribbean/Black British - Caribbean
# ...                                                   ...
# 140289        Other ethnic group - Any other ethnic group
# 140290   Asian/Asian British - Any other Asian background
# 140291        Other ethnic group - Any other ethnic group
# 140292                 White - Any other White background
# 140293                    Other ethnic group - Not stated
#
#        Officer-defined ethnicity  \
# 0                          Black
# 1                          Black
# 2                          White
# 3                          White
# 4                          Black
# ...                          ...
# 140289                     Other
# 140290                     Asian
# 140291                     Other
# 140292                     White
# 140293                     Other
#
#                                               Legislation  \
# 0       Police and Criminal Evidence Act 1984 (section 1)
# 1       Police and Criminal Evidence Act 1984 (section 1)
# 2       Police and Criminal Evidence Act 1984 (section 1)
# 3       Police and Criminal Evidence Act 1984 (section 1)
# 4       Police and Criminal Evidence Act 1984 (section 1)
# ...                                                   ...
# 140289              Misuse of Drugs Act 1971 (section 23)
# 140290              Misuse of Drugs Act 1971 (section 23)
# 140291              Misuse of Drugs Act 1971 (section 23)
# 140292              Misuse of Drugs Act 1971 (section 23)
# 140293              Misuse of Drugs Act 1971 (section 23)
#
#                 Object of search                       Outcome  \
# 0                   Stolen goods  A no further action disposal
# 1       Article for use in theft                        Arrest
# 2       Article for use in theft  A no further action disposal
# 3                   Stolen goods          Community resolution
# 4                   Stolen goods  A no further action disposal
# ...                          ...                           ...
# 140289          Controlled drugs          Community resolution
# 140290          Controlled drugs          Community resolution
# 140291          Controlled drugs          Community resolution
# 140292          Controlled drugs          Community resolution
# 140293          Controlled drugs          Community resolution
#
#        Outcome linked to object of search  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                     NaN
# 4                                   False
# ...                                   ...
# 140289                                NaN
# 140290                                NaN
# 140291                                NaN
# 140292                                NaN
# 140293                                NaN
#
#        Removal of more than just outer clothing  index_right    distance  \
# 0                                         False          0.0  160.042424
# 1                                         False          0.0  116.270257
# 2                                         False          0.0  127.020561
# 3                                           NaN          0.0  374.125238
# 4                                         False          0.0  311.926748
# ...                                         ...          ...         ...
# 140289                                      NaN       4664.0   55.143696
# 140290                                      NaN       4664.0   55.143696
# 140291                                      NaN       4664.0   55.143696
# 140292                                      NaN       4664.0   55.143696
# 140293                                      NaN       4664.0   55.143696
#
#                Borough
# 0       City of London
# 1       City of London
# 2       City of London
# 3       City of London
# 4       City of London
# ...                ...
# 140289     Westminster
# 140290     Westminster
# 140291     Westminster
# 140292     Westminster
# 140293     Westminster
#
# [140294 rows x 19 columns]

# %% [markdown]
# ## LSOA % non-white

# %% [markdown]
# https://www.nomisweb.co.uk/sources/census_2021_bulk

# %%
LSOA_ethnic = pd.read_csv('../data/LSOA_data/2021census_ethnic.csv') 

nonWhite =  (1- LSOA_ethnic['Ethnic group: White'] / LSOA_ethnic.iloc[:,3])*100
LSOA_ethnic
LSOA_ethnic = LSOA_ethnic.iloc[:, [2,3]]
LSOA_ethnic['nonWhite'] = round(nonWhite,2)
LSOA_ethnic.columns = ['LSOA code', 'population', 'nonWhite']

merseyside = merseyside.merge(LSOA_ethnic, on='LSOA code', how='left')
london = london.merge(LSOA_ethnic, on='LSOA code', how='left')

# %% [markdown]
# ## Crime Data

# %%
# Step 1: Fill NaNs in 'Outcome type' with values from 'Last outcome category'
crimes_df['Outcome type'] = crimes_df['Outcome type'].fillna(crimes_df['Last outcome category'])

# Step 2: Ensure that 'Outcome type' remains unchanged where it differs from 'Last outcome category'
crimes_df.loc[crimes_df['Last outcome category'] != crimes_df['Outcome type'], 'Outcome type'] = crimes_df['Outcome type']


crimes_df
# Out:
#                                                   Crime ID    Month  \
# 0        f344b946a36b4dc1db0a4bb889e8ec0fd23ab65aa2bf39...  2022-01
# 1        e74962917ce995fa9e52623b6fe0c218619b79d4a22550...  2022-01
# 2        067092d6822753127ce767d011ea5c5b4375de6f5a3c48...  2022-01
# 3                                                      NaN  2022-01
# 4                                                      NaN  2022-01
# ...                                                    ...      ...
# 1360391  7b127e4ff2fd1fdd40db3230cb20fac5af55b7cc66e2b9...  2022-12
# 1360392  5160c9abc5f0674f5f047e69c26f49f50f61f6e322131d...  2022-12
# 1360393  cee8aad8bb809fc0daefafd0d2fcece46fb554940212d0...  2022-12
# 1360394  8f12b9f524fc5c8ec0e3965f7d7ab406632a2b3549aa12...  2022-12
# 1360395  106dcbf7579082c309a6a01d4f95c6ea4fb9b7ddb3ee93...  2022-12
#
#                          Reported by                 Falls within  Longitude  \
# 0              City of London Police        City of London Police  -0.106453
# 1              City of London Police        City of London Police  -0.113256
# 2              City of London Police        City of London Police  -0.116100
# 3              City of London Police        City of London Police  -0.097601
# 4              City of London Police        City of London Police  -0.095914
# ...                              ...                          ...        ...
# 1360391  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1360392  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1360393  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1360394  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1360395  Metropolitan Police Service  Metropolitan Police Service        NaN
#
#           Latitude                        Location  LSOA code  \
# 0        51.518207  On or near Charterhouse Street  E01000916
# 1        51.516824           On or near Old Square  E01000914
# 2        51.518470          On or near Supermarket  E01000914
# 3        51.520699    On or near Carthusian Street  E01000001
# 4        51.520348         On or near Beech Street  E01000001
# ...            ...                             ...        ...
# 1360391        NaN                     No Location        NaN
# 1360392        NaN                     No Location        NaN
# 1360393        NaN                     No Location        NaN
# 1360394        NaN                     No Location        NaN
# 1360395        NaN                     No Location        NaN
#
#                    LSOA name             Crime type  \
# 0                Camden 027B               Burglary
# 1                Camden 028B            Other theft
# 2                Camden 028B            Other theft
# 3        City of London 001A  Anti-social behaviour
# 4        City of London 001A  Anti-social behaviour
# ...                      ...                    ...
# 1360391                  NaN            Other crime
# 1360392                  NaN            Other crime
# 1360393                  NaN            Other crime
# 1360394                  NaN            Other crime
# 1360395                  NaN            Other crime
#
#                                  Last outcome category  Context  \
# 0                            Status update unavailable      NaN
# 1        Investigation complete; no suspect identified      NaN
# 2                            Status update unavailable      NaN
# 3                                                  NaN      NaN
# 4                                                  NaN      NaN
# ...                                                ...      ...
# 1360391  Investigation complete; no suspect identified      NaN
# 1360392  Investigation complete; no suspect identified      NaN
# 1360393                       Offender given a caution      NaN
# 1360394                      Status update unavailable      NaN
# 1360395  Investigation complete; no suspect identified      NaN
#
#                                           Outcome type       Date
# 0                            Status update unavailable 2022-01-01
# 1        Investigation complete; no suspect identified 2022-01-01
# 2                            Status update unavailable 2022-01-01
# 3                                                  NaN 2022-01-01
# 4                                                  NaN 2022-01-01
# ...                                                ...        ...
# 1360391  Investigation complete; no suspect identified 2022-12-01
# 1360392  Investigation complete; no suspect identified 2022-12-01
# 1360393                       Offender given a caution 2022-12-01
# 1360394                      Status update unavailable 2022-12-01
# 1360395  Investigation complete; no suspect identified 2022-12-01
#
# [1360396 rows x 14 columns]

# %%
# crime and drug counts per LSOA
crime_counts = crimes_df['LSOA code'].value_counts().reset_index()
drug_counts = crimes_df.loc[crimes_df['Crime type'] == 'Drugs', 'LSOA code'].value_counts().reset_index()

drug_counts.columns = ['LSOA code', 'drug_sum']
crime_counts.columns = ['LSOA code', 'crime_sum']

# Merge with region data and calculate rates in one go
for df in [merseyside, london]:

    df = df.merge(crime_counts, on='LSOA code', how='left').merge(drug_counts, on='LSOA code', how='left')

    df['crimeRate'] = round(df['crime_sum'] / df['population'], 2)
    df['drugRate'] = round(df['drug_sum'] / df['population'], 2)


display(merseyside, london)  # Display final DataFrames
# Out:
#          index  LSOA code  mean_house_price                       Type  \
# 0      22486.0  E01006434       124940.0000  Person and Vehicle search
# 1      22486.0  E01006434       124940.0000              Person search
# 2      22486.0  E01006434       124940.0000              Person search
# 3      22486.0  E01006434       124940.0000              Person search
# 4      22486.0  E01006434       124940.0000              Person search
# ...        ...        ...               ...                        ...
# 37780      NaN  E01034836       146279.5293                        NaN
# 37781      NaN  E01034837       146279.5293                        NaN
# 37782      NaN  E01034838       146279.5293                        NaN
# 37783      NaN  E01034839       146279.5293                        NaN
# 37784      NaN  E01034840       146279.5293                        NaN
#
#                      Date   Latitude  Longitude Gender Age range  \
# 0     2022-01-16 16:57:20  53.476675  -2.875641   Male     18-24
# 1     2022-01-17 02:03:41  53.476675  -2.875641   Male     25-34
# 2     2022-01-19 18:37:52  53.475239  -2.867928   Male   over 34
# 3     2022-01-25 11:48:55  53.474090  -2.877502   Male     10-17
# 4     2022-01-31 11:23:07  53.474593  -2.876307   Male     25-34
# ...                   ...        ...        ...    ...       ...
# 37780                 NaT        NaN        NaN    NaN       NaN
# 37781                 NaT        NaN        NaN    NaN       NaN
# 37782                 NaT        NaN        NaN    NaN       NaN
# 37783                 NaT        NaN        NaN    NaN       NaN
# 37784                 NaT        NaN        NaN    NaN       NaN
#
#                                   Self-defined ethnicity  ...  \
# 0      Mixed/Multiple ethnic groups - Any other Mixed...  ...
# 1      White - English/Welsh/Scottish/Northern Irish/...  ...
# 2      White - English/Welsh/Scottish/Northern Irish/...  ...
# 3      White - English/Welsh/Scottish/Northern Irish/...  ...
# 4       Asian/Asian British - Any other Asian background  ...
# ...                                                  ...  ...
# 37780                                                NaN  ...
# 37781                                                NaN  ...
# 37782                                                NaN  ...
# 37783                                                NaN  ...
# 37784                                                NaN  ...
#
#                                              Legislation  \
# 0      Police and Criminal Evidence Act 1984 (section 1)
# 1      Police and Criminal Evidence Act 1984 (section 1)
# 2      Police and Criminal Evidence Act 1984 (section 1)
# 3                  Misuse of Drugs Act 1971 (section 23)
# 4      Police and Criminal Evidence Act 1984 (section 1)
# ...                                                  ...
# 37780                                                NaN
# 37781                                                NaN
# 37782                                                NaN
# 37783                                                NaN
# 37784                                                NaN
#
#                Object of search                       Outcome  \
# 0      Article for use in theft  A no further action disposal
# 1              Controlled drugs  A no further action disposal
# 2      Article for use in theft  A no further action disposal
# 3              Controlled drugs  A no further action disposal
# 4                  Stolen goods  A no further action disposal
# ...                         ...                           ...
# 37780                       NaN                           NaN
# 37781                       NaN                           NaN
# 37782                       NaN                           NaN
# 37783                       NaN                           NaN
# 37784                       NaN                           NaN
#
#       Outcome linked to object of search  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 37780                                NaN
# 37781                                NaN
# 37782                                NaN
# 37783                                NaN
# 37784                                NaN
#
#       Removal of more than just outer clothing index_right    distance  \
# 0                                        False      6433.0  171.438495
# 1                                        False      6433.0  171.438495
# 2                                        False      6433.0  454.001372
# 3                                        False      6433.0  221.084998
# 4                                        False      6433.0  124.013202
# ...                                        ...         ...         ...
# 37780                                      NaN         NaN         NaN
# 37781                                      NaN         NaN         NaN
# 37782                                      NaN         NaN         NaN
# 37783                                      NaN         NaN         NaN
# 37784                                      NaN         NaN         NaN
#
#         Borough population  nonWhite
# 0      Knowsley       1518      1.91
# 1      Knowsley       1518      1.91
# 2      Knowsley       1518      1.91
# 3      Knowsley       1518      1.91
# 4      Knowsley       1518      1.91
# ...         ...        ...       ...
# 37780    Wirral       1253      7.10
# 37781    Wirral       1638      6.59
# 37782    Wirral       1022      8.41
# 37783    Wirral       1043      7.86
# 37784    Wirral       1402      4.07
#
# [37785 rows x 21 columns]
#           index  LSOA code  mean_house_price           Type  \
# 0       28014.0  E01000001      1.110000e+07  Person search
# 1       28014.0  E01000001      1.110000e+07  Person search
# 2       28014.0  E01000001      1.110000e+07  Person search
# 3       28014.0  E01000001      1.110000e+07  Person search
# 4       28014.0  E01000001      1.110000e+07  Person search
# ...         ...        ...               ...            ...
# 140289  32738.0  E01004665      7.260344e+05  Person search
# 140290  32738.0  E01004665      7.260344e+05  Person search
# 140291  32738.0  E01004665      7.260344e+05  Person search
# 140292  32738.0  E01004665      7.260344e+05  Person search
# 140293  32738.0  E01004665      7.260344e+05  Person search
#
#                       Date   Latitude  Longitude Gender Age range  \
# 0      2022-01-10 02:40:15  51.520699  -0.097601   Male   over 34
# 1      2022-01-10 12:37:39  51.518864  -0.097562   Male   over 34
# 2      2022-01-20 05:14:39  51.520206  -0.097736   Male     10-17
# 3      2022-01-26 08:17:00  51.519703  -0.101649   Male     18-24
# 4      2022-02-04 08:59:46  51.517146  -0.098642   Male     18-24
# ...                    ...        ...        ...    ...       ...
# 140289 2022-12-16 20:20:00  51.485949  -0.141768   Male     18-24
# 140290 2022-12-16 20:20:00  51.485949  -0.141768   Male     18-24
# 140291 2022-12-16 20:20:00  51.485949  -0.141768   Male     18-24
# 140292 2022-12-16 20:25:00  51.485949  -0.141768   Male     18-24
# 140293 2022-12-16 20:25:00  51.485949  -0.141768   Male     18-24
#
#                                    Self-defined ethnicity  ...  \
# 0                         Other ethnic group - Not stated  ...
# 1       Mixed/Multiple ethnic groups - White and Black...  ...
# 2       White - English/Welsh/Scottish/Northern Irish/...  ...
# 3       White - English/Welsh/Scottish/Northern Irish/...  ...
# 4       Black/African/Caribbean/Black British - Caribbean  ...
# ...                                                   ...  ...
# 140289        Other ethnic group - Any other ethnic group  ...
# 140290   Asian/Asian British - Any other Asian background  ...
# 140291        Other ethnic group - Any other ethnic group  ...
# 140292                 White - Any other White background  ...
# 140293                    Other ethnic group - Not stated  ...
#
#                                               Legislation  \
# 0       Police and Criminal Evidence Act 1984 (section 1)
# 1       Police and Criminal Evidence Act 1984 (section 1)
# 2       Police and Criminal Evidence Act 1984 (section 1)
# 3       Police and Criminal Evidence Act 1984 (section 1)
# 4       Police and Criminal Evidence Act 1984 (section 1)
# ...                                                   ...
# 140289              Misuse of Drugs Act 1971 (section 23)
# 140290              Misuse of Drugs Act 1971 (section 23)
# 140291              Misuse of Drugs Act 1971 (section 23)
# 140292              Misuse of Drugs Act 1971 (section 23)
# 140293              Misuse of Drugs Act 1971 (section 23)
#
#                 Object of search                       Outcome  \
# 0                   Stolen goods  A no further action disposal
# 1       Article for use in theft                        Arrest
# 2       Article for use in theft  A no further action disposal
# 3                   Stolen goods          Community resolution
# 4                   Stolen goods  A no further action disposal
# ...                          ...                           ...
# 140289          Controlled drugs          Community resolution
# 140290          Controlled drugs          Community resolution
# 140291          Controlled drugs          Community resolution
# 140292          Controlled drugs          Community resolution
# 140293          Controlled drugs          Community resolution
#
#        Outcome linked to object of search  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                     NaN
# 4                                   False
# ...                                   ...
# 140289                                NaN
# 140290                                NaN
# 140291                                NaN
# 140292                                NaN
# 140293                                NaN
#
#        Removal of more than just outer clothing index_right    distance  \
# 0                                         False         0.0  160.042424
# 1                                         False         0.0  116.270257
# 2                                         False         0.0  127.020561
# 3                                           NaN         0.0  374.125238
# 4                                         False         0.0  311.926748
# ...                                         ...         ...         ...
# 140289                                      NaN      4664.0   55.143696
# 140290                                      NaN      4664.0   55.143696
# 140291                                      NaN      4664.0   55.143696
# 140292                                      NaN      4664.0   55.143696
# 140293                                      NaN      4664.0   55.143696
#
#                Borough population  nonWhite
# 0       City of London       1474     19.88
# 1       City of London       1474     19.88
# 2       City of London       1474     19.88
# 3       City of London       1474     19.88
# 4       City of London       1474     19.88
# ...                ...        ...       ...
# 140289     Westminster       1456     60.10
# 140290     Westminster       1456     60.10
# 140291     Westminster       1456     60.10
# 140292     Westminster       1456     60.10
# 140293     Westminster       1456     60.10
#
# [140294 rows x 21 columns]

# %% [markdown]
# ## Mapping the nearest station to the stop

# %% [markdown]
# https://github.com/davwheat/uk-railway-stations/blob/main/stations.csv

# %%
stations_df = pd.read_csv('https://raw.githubusercontent.com/davwheat/uk-railway-stations/refs/heads/main/stations.csv')

stations_df.columns = ['Name', 'Latitude', 'Longitude', 'code#1', 'code#2']
stations_df = stations_df[['Longitude', 'Latitude']]

stations_df
# Out:
#       Longitude   Latitude
# 0      0.120343  51.490719
# 1     -3.230890  51.575363
# 2     -3.329549  51.642620
# 3     -3.443130  51.715019
# 4     -2.097464  57.143127
# ...         ...        ...
# 2619  -4.387464  55.892792
# 2620  -1.093159  53.957966
# 2621  -2.736450  52.809009
# 2622  -3.241342  51.640884
# 2623  -3.475570  51.644478
#
# [2624 rows x 2 columns]

# %%
# Step 1: Convert Merseyside points to a GeoDataFrame
merseyside_map = gpd.GeoDataFrame(merseyside, 
                        geometry=gpd.points_from_xy(merseyside['Longitude'], 
                                                    merseyside['Latitude']),
                        crs="EPSG:4326")  # WGS84 (lat/lon)

london_map = gpd.GeoDataFrame(london, 
                        geometry=gpd.points_from_xy(london['Longitude'], 
                                                    london['Latitude']),
                        crs="EPSG:4326")  # WGS84 (lat/lon)


# Step 2: Convert Stations points to a GeoDataFrame
map_to_station = gpd.GeoDataFrame(stations_df, 
                        geometry=gpd.points_from_xy(stations_df['Longitude'], 
                                                    stations_df['Latitude']),
                        crs="EPSG:4326")  # WGS84 (lat/lon)

# Step 3: Reproject to British National Grid (EPSG:27700) for accurate distance measurements
merseyside_map = merseyside_map.to_crs("EPSG:27700")
london_map = london_map.to_crs("EPSG:27700")
map_to_station = map_to_station.to_crs("EPSG:27700")

# Step 4: Perform spatial join to map nearest train station to each Merseyside point
merseyside_results = gpd.sjoin_nearest(merseyside_map, map_to_station, how="left", distance_col="distance", lsuffix='_merseyside', rsuffix='_station')

london_results = gpd.sjoin_nearest(london_map, map_to_station, how="left", distance_col="distance", lsuffix='_london', rsuffix='_station')


# Step 5: Extract the list of distances
m_distances_list = merseyside_results['distance']
l_distances_list = london_results['distance']


# add the distances to dfs
merseyside['distStation'] = round(m_distances_list)
london['distStation'] = round(l_distances_list)

display(merseyside, london)
# Out:
#          index  LSOA code  mean_house_price                       Type  \
# 0      22486.0  E01006434       124940.0000  Person and Vehicle search
# 1      22486.0  E01006434       124940.0000              Person search
# 2      22486.0  E01006434       124940.0000              Person search
# 3      22486.0  E01006434       124940.0000              Person search
# 4      22486.0  E01006434       124940.0000              Person search
# ...        ...        ...               ...                        ...
# 37780      NaN  E01034836       146279.5293                        NaN
# 37781      NaN  E01034837       146279.5293                        NaN
# 37782      NaN  E01034838       146279.5293                        NaN
# 37783      NaN  E01034839       146279.5293                        NaN
# 37784      NaN  E01034840       146279.5293                        NaN
#
#                      Date   Latitude  Longitude Gender Age range  \
# 0     2022-01-16 16:57:20  53.476675  -2.875641   Male     18-24
# 1     2022-01-17 02:03:41  53.476675  -2.875641   Male     25-34
# 2     2022-01-19 18:37:52  53.475239  -2.867928   Male   over 34
# 3     2022-01-25 11:48:55  53.474090  -2.877502   Male     10-17
# 4     2022-01-31 11:23:07  53.474593  -2.876307   Male     25-34
# ...                   ...        ...        ...    ...       ...
# 37780                 NaT        NaN        NaN    NaN       NaN
# 37781                 NaT        NaN        NaN    NaN       NaN
# 37782                 NaT        NaN        NaN    NaN       NaN
# 37783                 NaT        NaN        NaN    NaN       NaN
# 37784                 NaT        NaN        NaN    NaN       NaN
#
#                                   Self-defined ethnicity  ...  \
# 0      Mixed/Multiple ethnic groups - Any other Mixed...  ...
# 1      White - English/Welsh/Scottish/Northern Irish/...  ...
# 2      White - English/Welsh/Scottish/Northern Irish/...  ...
# 3      White - English/Welsh/Scottish/Northern Irish/...  ...
# 4       Asian/Asian British - Any other Asian background  ...
# ...                                                  ...  ...
# 37780                                                NaN  ...
# 37781                                                NaN  ...
# 37782                                                NaN  ...
# 37783                                                NaN  ...
# 37784                                                NaN  ...
#
#                Object of search                       Outcome  \
# 0      Article for use in theft  A no further action disposal
# 1              Controlled drugs  A no further action disposal
# 2      Article for use in theft  A no further action disposal
# 3              Controlled drugs  A no further action disposal
# 4                  Stolen goods  A no further action disposal
# ...                         ...                           ...
# 37780                       NaN                           NaN
# 37781                       NaN                           NaN
# 37782                       NaN                           NaN
# 37783                       NaN                           NaN
# 37784                       NaN                           NaN
#
#       Outcome linked to object of search  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 37780                                NaN
# 37781                                NaN
# 37782                                NaN
# 37783                                NaN
# 37784                                NaN
#
#       Removal of more than just outer clothing index_right    distance  \
# 0                                        False      6433.0  171.438495
# 1                                        False      6433.0  171.438495
# 2                                        False      6433.0  454.001372
# 3                                        False      6433.0  221.084998
# 4                                        False      6433.0  124.013202
# ...                                        ...         ...         ...
# 37780                                      NaN         NaN         NaN
# 37781                                      NaN         NaN         NaN
# 37782                                      NaN         NaN         NaN
# 37783                                      NaN         NaN         NaN
# 37784                                      NaN         NaN         NaN
#
#         Borough  population nonWhite  distStation
# 0      Knowsley        1518     1.91       1811.0
# 1      Knowsley        1518     1.91       1811.0
# 2      Knowsley        1518     1.91       2088.0
# 3      Knowsley        1518     1.91       2087.0
# 4      Knowsley        1518     1.91       2037.0
# ...         ...         ...      ...          ...
# 37780    Wirral        1253     7.10          NaN
# 37781    Wirral        1638     6.59          NaN
# 37782    Wirral        1022     8.41          NaN
# 37783    Wirral        1043     7.86          NaN
# 37784    Wirral        1402     4.07          NaN
#
# [37785 rows x 22 columns]
#           index  LSOA code  mean_house_price           Type  \
# 0       28014.0  E01000001      1.110000e+07  Person search
# 1       28014.0  E01000001      1.110000e+07  Person search
# 2       28014.0  E01000001      1.110000e+07  Person search
# 3       28014.0  E01000001      1.110000e+07  Person search
# 4       28014.0  E01000001      1.110000e+07  Person search
# ...         ...        ...               ...            ...
# 140289  32738.0  E01004665      7.260344e+05  Person search
# 140290  32738.0  E01004665      7.260344e+05  Person search
# 140291  32738.0  E01004665      7.260344e+05  Person search
# 140292  32738.0  E01004665      7.260344e+05  Person search
# 140293  32738.0  E01004665      7.260344e+05  Person search
#
#                       Date   Latitude  Longitude Gender Age range  \
# 0      2022-01-10 02:40:15  51.520699  -0.097601   Male   over 34
# 1      2022-01-10 12:37:39  51.518864  -0.097562   Male   over 34
# 2      2022-01-20 05:14:39  51.520206  -0.097736   Male     10-17
# 3      2022-01-26 08:17:00  51.519703  -0.101649   Male     18-24
# 4      2022-02-04 08:59:46  51.517146  -0.098642   Male     18-24
# ...                    ...        ...        ...    ...       ...
# 140289 2022-12-16 20:20:00  51.485949  -0.141768   Male     18-24
# 140290 2022-12-16 20:20:00  51.485949  -0.141768   Male     18-24
# 140291 2022-12-16 20:20:00  51.485949  -0.141768   Male     18-24
# 140292 2022-12-16 20:25:00  51.485949  -0.141768   Male     18-24
# 140293 2022-12-16 20:25:00  51.485949  -0.141768   Male     18-24
#
#                                    Self-defined ethnicity  ...  \
# 0                         Other ethnic group - Not stated  ...
# 1       Mixed/Multiple ethnic groups - White and Black...  ...
# 2       White - English/Welsh/Scottish/Northern Irish/...  ...
# 3       White - English/Welsh/Scottish/Northern Irish/...  ...
# 4       Black/African/Caribbean/Black British - Caribbean  ...
# ...                                                   ...  ...
# 140289        Other ethnic group - Any other ethnic group  ...
# 140290   Asian/Asian British - Any other Asian background  ...
# 140291        Other ethnic group - Any other ethnic group  ...
# 140292                 White - Any other White background  ...
# 140293                    Other ethnic group - Not stated  ...
#
#                 Object of search                       Outcome  \
# 0                   Stolen goods  A no further action disposal
# 1       Article for use in theft                        Arrest
# 2       Article for use in theft  A no further action disposal
# 3                   Stolen goods          Community resolution
# 4                   Stolen goods  A no further action disposal
# ...                          ...                           ...
# 140289          Controlled drugs          Community resolution
# 140290          Controlled drugs          Community resolution
# 140291          Controlled drugs          Community resolution
# 140292          Controlled drugs          Community resolution
# 140293          Controlled drugs          Community resolution
#
#        Outcome linked to object of search  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                     NaN
# 4                                   False
# ...                                   ...
# 140289                                NaN
# 140290                                NaN
# 140291                                NaN
# 140292                                NaN
# 140293                                NaN
#
#        Removal of more than just outer clothing index_right    distance  \
# 0                                         False         0.0  160.042424
# 1                                         False         0.0  116.270257
# 2                                         False         0.0  127.020561
# 3                                           NaN         0.0  374.125238
# 4                                         False         0.0  311.926748
# ...                                         ...         ...         ...
# 140289                                      NaN      4664.0   55.143696
# 140290                                      NaN      4664.0   55.143696
# 140291                                      NaN      4664.0   55.143696
# 140292                                      NaN      4664.0   55.143696
# 140293                                      NaN      4664.0   55.143696
#
#                Borough  population nonWhite  distStation
# 0       City of London        1474    19.88        495.0
# 1       City of London        1474    19.88        507.0
# 2       City of London        1474    19.88        481.0
# 3       City of London        1474    19.88        213.0
# 4       City of London        1474    19.88        455.0
# ...                ...         ...      ...          ...
# 140289     Westminster        1456    60.10       1062.0
# 140290     Westminster        1456    60.10       1062.0
# 140291     Westminster        1456    60.10       1062.0
# 140292     Westminster        1456    60.10       1062.0
# 140293     Westminster        1456    60.10       1062.0
#
# [140294 rows x 22 columns]

# %% [markdown]
# ## Index of Multiple Deprivation (IMD)

# %% [markdown]
# https://www.gov.uk/government/statistics/english-indices-of-deprivation-2019

# %%
LSAO_IMD = pd.read_excel('../data/LSOA_data/Index_of_Multiple_Deprivation.xlsx',
              sheet_name=1)


LSAO_IMD = LSAO_IMD.iloc[:,[0,-1, -2]]
LSAO_IMD.columns = ['LSOA code', 'IMDDecile', 'IMDRank']

LSAO_IMD
# Out:
#        LSOA code  IMDDecile  IMDRank
# 0      E01000001          9    29199
# 1      E01000002         10    30379
# 2      E01000003          5    14915
# 3      E01000005          3     8678
# 4      E01000006          5    14486
# ...          ...        ...      ...
# 32839  E01033764          1      116
# 32840  E01033765          1      945
# 32841  E01033766          4    12842
# 32842  E01033767          1      422
# 32843  E01033768          1     1833
#
# [32844 rows x 3 columns]

# %%
merseyside = merseyside.merge(LSAO_IMD, on='LSOA code', how='left')
london = london.merge(LSAO_IMD, on='LSOA code', how='left')

display(london.head(), merseyside.head())
# Out:
#      index  LSOA code  mean_house_price           Type                Date  \
# 0  28014.0  E01000001        11100000.0  Person search 2022-01-10 02:40:15
# 1  28014.0  E01000001        11100000.0  Person search 2022-01-10 12:37:39
# 2  28014.0  E01000001        11100000.0  Person search 2022-01-20 05:14:39
# 3  28014.0  E01000001        11100000.0  Person search 2022-01-26 08:17:00
# 4  28014.0  E01000001        11100000.0  Person search 2022-02-04 08:59:46
#
#     Latitude  Longitude Gender Age range  \
# 0  51.520699  -0.097601   Male   over 34
# 1  51.518864  -0.097562   Male   over 34
# 2  51.520206  -0.097736   Male     10-17
# 3  51.519703  -0.101649   Male     18-24
# 4  51.517146  -0.098642   Male     18-24
#
#                               Self-defined ethnicity  ...  \
# 0                    Other ethnic group - Not stated  ...
# 1  Mixed/Multiple ethnic groups - White and Black...  ...
# 2  White - English/Welsh/Scottish/Northern Irish/...  ...
# 3  White - English/Welsh/Scottish/Northern Irish/...  ...
# 4  Black/African/Caribbean/Black British - Caribbean  ...
#
#   Outcome linked to object of search Removal of more than just outer clothing  \
# 0                              False                                    False
# 1                               True                                    False
# 2                              False                                    False
# 3                                NaN                                      NaN
# 4                              False                                    False
#
#   index_right    distance         Borough population  nonWhite  distStation  \
# 0         0.0  160.042424  City of London       1474     19.88        495.0
# 1         0.0  116.270257  City of London       1474     19.88        507.0
# 2         0.0  127.020561  City of London       1474     19.88        481.0
# 3         0.0  374.125238  City of London       1474     19.88        213.0
# 4         0.0  311.926748  City of London       1474     19.88        455.0
#
#   IMDDecile  IMDRank
# 0       9.0  29199.0
# 1       9.0  29199.0
# 2       9.0  29199.0
# 3       9.0  29199.0
# 4       9.0  29199.0
#
# [5 rows x 24 columns]
#      index  LSOA code  mean_house_price                       Type  \
# 0  22486.0  E01006434          124940.0  Person and Vehicle search
# 1  22486.0  E01006434          124940.0              Person search
# 2  22486.0  E01006434          124940.0              Person search
# 3  22486.0  E01006434          124940.0              Person search
# 4  22486.0  E01006434          124940.0              Person search
#
#                  Date   Latitude  Longitude Gender Age range  \
# 0 2022-01-16 16:57:20  53.476675  -2.875641   Male     18-24
# 1 2022-01-17 02:03:41  53.476675  -2.875641   Male     25-34
# 2 2022-01-19 18:37:52  53.475239  -2.867928   Male   over 34
# 3 2022-01-25 11:48:55  53.474090  -2.877502   Male     10-17
# 4 2022-01-31 11:23:07  53.474593  -2.876307   Male     25-34
#
#                               Self-defined ethnicity  ...  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...  ...
# 1  White - English/Welsh/Scottish/Northern Irish/...  ...
# 2  White - English/Welsh/Scottish/Northern Irish/...  ...
# 3  White - English/Welsh/Scottish/Northern Irish/...  ...
# 4   Asian/Asian British - Any other Asian background  ...
#
#   Outcome linked to object of search Removal of more than just outer clothing  \
# 0                                NaN                                    False
# 1                                NaN                                    False
# 2                                NaN                                    False
# 3                                NaN                                    False
# 4                                NaN                                    False
#
#   index_right    distance   Borough population  nonWhite  distStation  \
# 0      6433.0  171.438495  Knowsley       1518      1.91       1811.0
# 1      6433.0  171.438495  Knowsley       1518      1.91       1811.0
# 2      6433.0  454.001372  Knowsley       1518      1.91       2088.0
# 3      6433.0  221.084998  Knowsley       1518      1.91       2087.0
# 4      6433.0  124.013202  Knowsley       1518      1.91       2037.0
#
#   IMDDecile  IMDRank
# 0       1.0    694.0
# 1       1.0    694.0
# 2       1.0    694.0
# 3       1.0    694.0
# 4       1.0    694.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Aggregate Stop and Search Rate

# %% [markdown]
# could maybe do this way before

# %%
stops_per_lsoa_merseyside = merseyside.groupby('LSOA code')['Outcome'].count().reset_index()
stops_per_lsoa_london = london.groupby('LSOA code')['Outcome'].count().reset_index()


stops_per_lsoa = stops_per_lsoa_merseyside.rename(columns={'Outcome': 'stop_count'})
merseyside = merseyside.merge( stops_per_lsoa, on='LSOA code', how='left')


stops_per_lsoa = stops_per_lsoa_london.rename(columns={'Outcome': 'stop_count'})
london = london.merge( stops_per_lsoa, on='LSOA code', how='left')


merseyside['stops_per_LSOA'] = round(merseyside['stop_count'] / merseyside['population'] * 100,2)
merseyside['stops_per_1000'] = round(merseyside['stop_count'] / 10,2)

london['stops_per_LSOA'] = round(london['stop_count'] / merseyside['population'] * 100,2)
london['stops_per_1000'] = round(london['stop_count'] / 10,2)


display(london.head(), merseyside.head())
# Out:
#      index  LSOA code  mean_house_price           Type                Date  \
# 0  28014.0  E01000001        11100000.0  Person search 2022-01-10 02:40:15
# 1  28014.0  E01000001        11100000.0  Person search 2022-01-10 12:37:39
# 2  28014.0  E01000001        11100000.0  Person search 2022-01-20 05:14:39
# 3  28014.0  E01000001        11100000.0  Person search 2022-01-26 08:17:00
# 4  28014.0  E01000001        11100000.0  Person search 2022-02-04 08:59:46
#
#     Latitude  Longitude Gender Age range  \
# 0  51.520699  -0.097601   Male   over 34
# 1  51.518864  -0.097562   Male   over 34
# 2  51.520206  -0.097736   Male     10-17
# 3  51.519703  -0.101649   Male     18-24
# 4  51.517146  -0.098642   Male     18-24
#
#                               Self-defined ethnicity  ...    distance  \
# 0                    Other ethnic group - Not stated  ...  160.042424
# 1  Mixed/Multiple ethnic groups - White and Black...  ...  116.270257
# 2  White - English/Welsh/Scottish/Northern Irish/...  ...  127.020561
# 3  White - English/Welsh/Scottish/Northern Irish/...  ...  374.125238
# 4  Black/African/Caribbean/Black British - Caribbean  ...  311.926748
#
#           Borough population nonWhite distStation IMDDecile  IMDRank  \
# 0  City of London       1474    19.88       495.0       9.0  29199.0
# 1  City of London       1474    19.88       507.0       9.0  29199.0
# 2  City of London       1474    19.88       481.0       9.0  29199.0
# 3  City of London       1474    19.88       213.0       9.0  29199.0
# 4  City of London       1474    19.88       455.0       9.0  29199.0
#
#    stop_count stops_per_LSOA  stops_per_1000
# 0          94           6.19             9.4
# 1          94           6.19             9.4
# 2          94           6.19             9.4
# 3          94           6.19             9.4
# 4          94           6.19             9.4
#
# [5 rows x 27 columns]
#      index  LSOA code  mean_house_price                       Type  \
# 0  22486.0  E01006434          124940.0  Person and Vehicle search
# 1  22486.0  E01006434          124940.0              Person search
# 2  22486.0  E01006434          124940.0              Person search
# 3  22486.0  E01006434          124940.0              Person search
# 4  22486.0  E01006434          124940.0              Person search
#
#                  Date   Latitude  Longitude Gender Age range  \
# 0 2022-01-16 16:57:20  53.476675  -2.875641   Male     18-24
# 1 2022-01-17 02:03:41  53.476675  -2.875641   Male     25-34
# 2 2022-01-19 18:37:52  53.475239  -2.867928   Male   over 34
# 3 2022-01-25 11:48:55  53.474090  -2.877502   Male     10-17
# 4 2022-01-31 11:23:07  53.474593  -2.876307   Male     25-34
#
#                               Self-defined ethnicity  ...    distance  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...  ...  171.438495
# 1  White - English/Welsh/Scottish/Northern Irish/...  ...  171.438495
# 2  White - English/Welsh/Scottish/Northern Irish/...  ...  454.001372
# 3  White - English/Welsh/Scottish/Northern Irish/...  ...  221.084998
# 4   Asian/Asian British - Any other Asian background  ...  124.013202
#
#     Borough population nonWhite distStation IMDDecile  IMDRank  stop_count  \
# 0  Knowsley       1518     1.91      1811.0       1.0    694.0         114
# 1  Knowsley       1518     1.91      1811.0       1.0    694.0         114
# 2  Knowsley       1518     1.91      2088.0       1.0    694.0         114
# 3  Knowsley       1518     1.91      2087.0       1.0    694.0         114
# 4  Knowsley       1518     1.91      2037.0       1.0    694.0         114
#
#   stops_per_LSOA  stops_per_1000
# 0           7.51            11.4
# 1           7.51            11.4
# 2           7.51            11.4
# 3           7.51            11.4
# 4           7.51            11.4
#
# [5 rows x 27 columns]

# %% [markdown]
# # Final Touches

# %% [markdown]
# ### Remove useless columns

# %%
cols_to_drop = ['index', 'index_right',  'distance']

merseyside = merseyside.drop(columns=cols_to_drop)
london = london.drop(columns=cols_to_drop)

# %% [markdown]
# ### Rename columns to be more efficient

# %%
cols = ['LSOA21CD', 'hprice', 'type', 'date', 'lat', 'long', 'gender', 'age', 'selfEthnic', 'officerEthnic', 'leg', 'obj', 'outcome',
        'link', 'rmCloth', 'borough', 'pop', 'nonWhite', 'distStation', 'IMDDecile', 'IMDRank', 'stopsLSOAtotal', 'stopsLSOA', 'stops1000' ]

merseyside.columns = cols
london.columns = cols

display(merseyside, london)
# Out:
#         LSOA21CD       hprice                       type                date  \
# 0      E01006434  124940.0000  Person and Vehicle search 2022-01-16 16:57:20
# 1      E01006434  124940.0000              Person search 2022-01-17 02:03:41
# 2      E01006434  124940.0000              Person search 2022-01-19 18:37:52
# 3      E01006434  124940.0000              Person search 2022-01-25 11:48:55
# 4      E01006434  124940.0000              Person search 2022-01-31 11:23:07
# ...          ...          ...                        ...                 ...
# 37780  E01034836  146279.5293                        NaN                 NaT
# 37781  E01034837  146279.5293                        NaN                 NaT
# 37782  E01034838  146279.5293                        NaN                 NaT
# 37783  E01034839  146279.5293                        NaN                 NaT
# 37784  E01034840  146279.5293                        NaN                 NaT
#
#              lat      long gender      age  \
# 0      53.476675 -2.875641   Male    18-24
# 1      53.476675 -2.875641   Male    25-34
# 2      53.475239 -2.867928   Male  over 34
# 3      53.474090 -2.877502   Male    10-17
# 4      53.474593 -2.876307   Male    25-34
# ...          ...       ...    ...      ...
# 37780        NaN       NaN    NaN      NaN
# 37781        NaN       NaN    NaN      NaN
# 37782        NaN       NaN    NaN      NaN
# 37783        NaN       NaN    NaN      NaN
# 37784        NaN       NaN    NaN      NaN
#
#                                               selfEthnic officerEthnic  ...  \
# 0      Mixed/Multiple ethnic groups - Any other Mixed...         Black  ...
# 1      White - English/Welsh/Scottish/Northern Irish/...         White  ...
# 2      White - English/Welsh/Scottish/Northern Irish/...         White  ...
# 3      White - English/Welsh/Scottish/Northern Irish/...         White  ...
# 4       Asian/Asian British - Any other Asian background         Asian  ...
# ...                                                  ...           ...  ...
# 37780                                                NaN           NaN  ...
# 37781                                                NaN           NaN  ...
# 37782                                                NaN           NaN  ...
# 37783                                                NaN           NaN  ...
# 37784                                                NaN           NaN  ...
#
#       rmCloth   borough   pop nonWhite distStation IMDDecile  IMDRank  \
# 0       False  Knowsley  1518     1.91      1811.0       1.0    694.0
# 1       False  Knowsley  1518     1.91      1811.0       1.0    694.0
# 2       False  Knowsley  1518     1.91      2088.0       1.0    694.0
# 3       False  Knowsley  1518     1.91      2087.0       1.0    694.0
# 4       False  Knowsley  1518     1.91      2037.0       1.0    694.0
# ...       ...       ...   ...      ...         ...       ...      ...
# 37780     NaN    Wirral  1253     7.10         NaN       NaN      NaN
# 37781     NaN    Wirral  1638     6.59         NaN       NaN      NaN
# 37782     NaN    Wirral  1022     8.41         NaN       NaN      NaN
# 37783     NaN    Wirral  1043     7.86         NaN       NaN      NaN
# 37784     NaN    Wirral  1402     4.07         NaN       NaN      NaN
#
#        stopsLSOAtotal  stopsLSOA  stops1000
# 0                 114       7.51       11.4
# 1                 114       7.51       11.4
# 2                 114       7.51       11.4
# 3                 114       7.51       11.4
# 4                 114       7.51       11.4
# ...               ...        ...        ...
# 37780               0       0.00        0.0
# 37781               0       0.00        0.0
# 37782               0       0.00        0.0
# 37783               0       0.00        0.0
# 37784               0       0.00        0.0
#
# [37785 rows x 24 columns]
#          LSOA21CD        hprice           type                date        lat  \
# 0       E01000001  1.110000e+07  Person search 2022-01-10 02:40:15  51.520699
# 1       E01000001  1.110000e+07  Person search 2022-01-10 12:37:39  51.518864
# 2       E01000001  1.110000e+07  Person search 2022-01-20 05:14:39  51.520206
# 3       E01000001  1.110000e+07  Person search 2022-01-26 08:17:00  51.519703
# 4       E01000001  1.110000e+07  Person search 2022-02-04 08:59:46  51.517146
# ...           ...           ...            ...                 ...        ...
# 140289  E01004665  7.260344e+05  Person search 2022-12-16 20:20:00  51.485949
# 140290  E01004665  7.260344e+05  Person search 2022-12-16 20:20:00  51.485949
# 140291  E01004665  7.260344e+05  Person search 2022-12-16 20:20:00  51.485949
# 140292  E01004665  7.260344e+05  Person search 2022-12-16 20:25:00  51.485949
# 140293  E01004665  7.260344e+05  Person search 2022-12-16 20:25:00  51.485949
#
#             long gender      age  \
# 0      -0.097601   Male  over 34
# 1      -0.097562   Male  over 34
# 2      -0.097736   Male    10-17
# 3      -0.101649   Male    18-24
# 4      -0.098642   Male    18-24
# ...          ...    ...      ...
# 140289 -0.141768   Male    18-24
# 140290 -0.141768   Male    18-24
# 140291 -0.141768   Male    18-24
# 140292 -0.141768   Male    18-24
# 140293 -0.141768   Male    18-24
#
#                                                selfEthnic officerEthnic  ...  \
# 0                         Other ethnic group - Not stated         Black  ...
# 1       Mixed/Multiple ethnic groups - White and Black...         Black  ...
# 2       White - English/Welsh/Scottish/Northern Irish/...         White  ...
# 3       White - English/Welsh/Scottish/Northern Irish/...         White  ...
# 4       Black/African/Caribbean/Black British - Caribbean         Black  ...
# ...                                                   ...           ...  ...
# 140289        Other ethnic group - Any other ethnic group         Other  ...
# 140290   Asian/Asian British - Any other Asian background         Asian  ...
# 140291        Other ethnic group - Any other ethnic group         Other  ...
# 140292                 White - Any other White background         White  ...
# 140293                    Other ethnic group - Not stated         Other  ...
#
#        rmCloth         borough   pop nonWhite distStation IMDDecile  IMDRank  \
# 0        False  City of London  1474    19.88       495.0       9.0  29199.0
# 1        False  City of London  1474    19.88       507.0       9.0  29199.0
# 2        False  City of London  1474    19.88       481.0       9.0  29199.0
# 3          NaN  City of London  1474    19.88       213.0       9.0  29199.0
# 4        False  City of London  1474    19.88       455.0       9.0  29199.0
# ...        ...             ...   ...      ...         ...       ...      ...
# 140289     NaN     Westminster  1456    60.10      1062.0       2.0   5376.0
# 140290     NaN     Westminster  1456    60.10      1062.0       2.0   5376.0
# 140291     NaN     Westminster  1456    60.10      1062.0       2.0   5376.0
# 140292     NaN     Westminster  1456    60.10      1062.0       2.0   5376.0
# 140293     NaN     Westminster  1456    60.10      1062.0       2.0   5376.0
#
#         stopsLSOAtotal  stopsLSOA  stops1000
# 0                   94       6.19        9.4
# 1                   94       6.19        9.4
# 2                   94       6.19        9.4
# 3                   94       6.19        9.4
# 4                   94       6.19        9.4
# ...                ...        ...        ...
# 140289             121        NaN       12.1
# 140290             121        NaN       12.1
# 140291             121        NaN       12.1
# 140292             121        NaN       12.1
# 140293             121        NaN       12.1
#
# [140294 rows x 24 columns]

# %% [markdown]
# ### Save to CSV

# %%
merseyside.to_csv(f'../data/merseyside{csv_names[1].split('/')[3][:4]}.csv')
london.to_csv(f'../data/london{csv_names[1].split('/')[3][:4]}.csv')
